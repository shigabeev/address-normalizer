# %% [markdown]
# # ElasticSearch + эвристики
# Или берём лучшее от двух предыдущих версий стандартизатора адресов

# %%
import pandas as pd
import random
import re
from elasticsearch import Elasticsearch as es
pd.options.display.max_columns = None
import itertools,operator

# %%
'''
Не работает без Elastic с загруженным туда ФИАС и проиндексированным на поиск родителей каждой строки
'''
from elasticsearch import Elasticsearch
es = Elasticsearch()

# %%
"""
Словарь, который используется для детекции номера дома, корпуса и т.д.
"""
sep_house_signs = {
  'дом': {'д', 'дом'},
  'владение':{'владение', 'вл'},
  'корпус': {'к', 'корп', 'копр', 'кор', 'корпус'},
  'строение':{'с', 'стр', 'строен', 'строение'},
  'квартира': {'кв', 'квартира'},
  'помещение':{'пом', 'помещение'},
  'комната':{"ком",'комн', 'комната'},
  'кабинет':{"кабинет", "каб", "к-т", "каб-т"},
  'офис': {'оф', 'офис'},
  'литера': set("абвежз"),
  'прочее': {'литер', 'литера', 'лит'}
}

# %%
house_signs_inv = inverdic(sep_house_signs)

# %%
def verify_address(full_address, debug=False):
  '''
  Ищет адрес в ФИАС
  Вход: строка
  Выход: словарь с полным адресом по ФИАС и его составляющими
  '''
  if full_address == '':
    return []
  query = {
  'size':1,
  "query":{
    "query_string" : {
            "fields" : ["fullname"],
            "query" : preprocess_for_search(full_address),
            "fuzziness": "auto",
            "use_dis_max" :  "true"
        }
  }
  }
  response = es.search(index='fias_full_text', doc_type='address', body=query)
  try:
    return response["hits"]["hits"][0]["_source"]
  except IndexError:
    return []
#   # Найти номер дома в ФИАС
#   if dic.get('Улица', False):
#     response.update(verify_home(dic, response['guid']))
#   response.update({'original':dic['original']})
#   if not debug:
#     try:
#       return response
#     except:
#       return []
#   else:
#     return response

# %%
def del_sp_char(string):
  '''
  Стоплист. Удаляет из строки символы переноса строки, но словарь можно дополнить при надобности
  '''
  for stopword in {r'\n', r'\r', '\\', '/', '(', ')', ':'}:
    string = string.replace(stopword, ' ')
  return re.sub(r"[\d]+", ' \g<0> ', string)

# %%
def preprocess(string):
  string = del_sp_char(string)
  string = re.sub(r"[\d]+", ' \g<0> ', string)
  string = string.replace(',', ', ')
  string = re.sub(r' +', ' ', string)
  return string

# %%
def preprocess_for_search(string):
  
  return string

# %%
def extract_index(string, errors=False):   # 100% works !!!
  '''
  Извлекает индекс из строки
  Вход: строка
  Выход: адрес без индекса, индекс
  '''
  index = re.findall(r'[^| |,][\d]{5}[ |$|, ]', string)
  if len(index) > 1 and errors:
    print("Два индекса в строке \"%s\" ?"%string)

  if index != []:
    index = index[0]
    string = string.replace(index, '').strip()
    index = index.replace(',', '')
  else:
    index = None
  return string, index

# %%
def tokenize(string, comma=False):
  '''
  Токенизатор. Раздвигает слипшиеся буквы и цифры вроде 2с3 или корп1
  Вход: строка
  Выход: массив из слов (токены)
  '''
  # string = re.sub(r"[\d]+", ' \g<0> ', string).lower() — это уже сделано при препроцессинге
  string = string.lower()
  if not comma:
    return re.findall(r'[\d]+|[\w]+', string)
  if comma:
    return re.findall(r'[\d]+|[\w]+|\,', string)

# %% [markdown]
# ## Извлечение дома

# %%
def extract_house_tokens(tokens):
  a = lambda x: "число" if x.isdigit() and len(x)<6 else "препинания" if x == ',' else "не распознано"
  types = [house_signs_inv.get(x, a(x)) for x in tokens]
  types_bin = [0 if x=='не распознано' else 1  for x in types]
  array = list((list(y) for (x,y) in itertools.groupby((enumerate(types_bin)),operator.itemgetter(1)) if x == 1))
  if len(array) == 0:
    return [], []
  longest_seq = max(reversed(array), key=len)
  return [tokens[i] for (i, _) in longest_seq], [types[i] for (i, _) in longest_seq]

# %%
def extract_house(string): #from 2.0
  '''
  Обёртка для процедуры извлечения номера дома/корпуса от оставшейся строки
  Вход: адрес(строка)
  Выход: адрес без номеров дома/корпуса, номера дома/корпуса строкой
  '''
  tokens = tokenize(string, comma=True)
  house_tokens, house_types = extract_house_tokens(tokens)
  
  pattern = r".?.?".join(house_tokens)
  found = re.search(pattern, string.lower())
  if found==None:
    split = len(string)
  else:
    split = found.start()
  #split = re.search(pattern, string.lower()).start()
  address = string[:split]
  house = string[split:]
  return address, house

# %%
def search_dict(word, dic):
  '''
  Поиск по словарю. Ищет по всем вложенным рубрикам словаря и возвращает путь к найденному слову
  Вход: токен (должен быть написан маленькими буквами) и опционально словарь
  Выход: Путь к слову/несколько путей
  '''
  if isinstance(dic, dict):
    winners = []
    for key, value in dic.items():
      response = search_dict(word, value)
      if response == True:
        winners.append(key)
      elif isinstance(response, list):
        for instance in response:
          if isinstance(instance, list):
            winners.append([key, *instance])
          else:
            winners.append([key, instance])
      elif isinstance(response, str):
        winners.append([key, response])
    return winners
  elif isinstance(dic, set) or isinstance(dic, list):
    if word in dic:
      return True

# %% [raw]
# def cut_house(block):
#   '''
#   Старый метод по обнаружению номеров дома/корпуса. Работает только с токенами
#   Вход: список слов
#   Выход: номер токена, с которого начинается адрес
#   '''
#   cut_ind = False
#   for i in reversed(range(len(block))):
#     block[i] = block[i].lower()
#     if search_dict(block[i], sep_house_signs):
#       if i+1<len(block) and (block[i+1].isdigit() or (block[i+1] in sep_house_signs['литера'])):
#         cut_ind = i
#     elif block[i].isdigit():
#       cut_ind=i
#     else:
#       return cut_ind
#   return cut_ind

# %%
def standardize(string, origin = True):
  '''
  Обёртка для всех методов выше. Разделяет адрес на его составляющие и ищет совпадение в ФИАС. В 90+% случаев находит.
  Вход: строка с адресом
  Выход: составляющие адреса
  '''
  dic = {}
  if origin:
    dic['origin'] = string
  string = preprocess(string)
  address, index = extract_index(string)
  address, house = extract_house(address)
  dic['index']=index
  dic['address'] = address
  dic.update(verify_address(address))
  dic['house'] = house
  return dic

# %%
def get_addr(strings, progress=True):
  '''
  Обрабатывает несколько адресов подряд.
  Вход: массив строк
  Выход: pandas Dataframe
  '''
  dics = []
  n = len(strings) - 1
  for i,  line in enumerate(strings):
    if progress:
      print("Working on {0} of {1}. Progress {2:03.1f}%".format(i, n, (i/n)*100), end='\r')
    dics.append(standardize(line))
  return pd.DataFrame(dics)

# %% [markdown]
# ## Методы для контроля качества

# %%
def score(ref, orig_col="Исходный адрес", func = get_addr, cols_to_score = ["Регион", "Район", "Город", "Н/п", "Улица"]):
  df_1 = func(ref[orig_col]).rename(index=str, columns=dadata_LUT)
  ref, df_1 = ref.fillna(''), df_1.fillna('')
  #### Не проверялось, так что может не работать
  df_1 = df_1.to_dict(orient='records')
  N = ref.shape[0]
  ref=ref.to_dict(orient='records')
  n = 0
  correct = 0
  df = []
  if len(df_1) != len(ref):
    return "не совпадают размеры таблицы"
  for i, row in enumerate(ref):
    for key, value in row.items():
      if key in cols_to_score:   #["Регион", "Индекс", "Район", "Город", "Н/п", "Улица", "Дом", "Корпус/строение"]:
        n += 1
        if value == df_1[i][key]:
          correct += 1
        else:
          df.append(df_1[i])
  print("\n{0:03.1f}% correct fields".format(correct/n*100))
  df = pd.DataFrame(df).drop_duplicates()
  print("\n{0:03.1f}% correct lines".format((N-df.shape[0])/N*100))
  return df.sample(20)

# %%
def show_changes(df1, df2):
  '''
  Выводит список изменений между df1 и df2
  '''
  if df1.shape != df2.shape:
    print("Разные таблицы")
    return
  df1, df2 = df1.fillna(''), df2.fillna('')
  delta_cols = list(df1.columns[(df1 != df2).any(0)])
  print("Изменились столбцы " + ", ".join(delta_cols))
  n = 0
  for col in delta_cols:
    diffs = df1[col] != df2[col]
    changes = set()
    n_i = 0
    for index, changed in diffs.iteritems():
      if changed:
        out = str(df1.iloc[index][col]) + ' ==> ' + str(df2.iloc[index][col])
        n += 1
        n_i +=1
        if out not in changes:
          changes.add(out)
          print(out)
    print("{} изменений в столбце".format(n_i))
  print("Всего изменено {} значений".format(n))

# %%
dadata_LUT = {'original':'Исходный адрес',
  'fullname':'Адрес',
  'postalcode':'Индекс',
  'country':'Страна',
  'region_type':'Тип региона',
  'region':'Регион',
  'area_type':'Тип района',
  'area':'Район',
  'city_type':'Тип города',
  'city':'Город',
  '65_type':'Тип н/п',
  '65':'Н/п',
  '???':'Адм. округ',
  'town':'Н/п',
  'town_type':'Тип н/п',
  'district_type':'Тип района',
  'district':'Район города',
  'street_type':'Тип улицы',
  'street':'Улица',
  'house_type':'Тип дома',
  'housenum':'Дом',
  'build_type':'Тип корпуса/строения',
  'buildnum':'Корпус/строение',
  'struc_type':'Тип корпуса/строения',
  'strucnum':'Корпус/строение',            
  'flat_type':'Тип квартиры',
  'flat_num':'Номер Квартиры'
}
# def rename_fias(dic, LUT=dadata_LUT):
#   return {LUT.get(key, key):value for key, value in dic.items() if key not in ['aolevel','guid', 'houseid', 'district_type']}

# %% [markdown]
# ### TODO:
# 1. отцеплять адреса по 2.0 технологии
# 2. Дробить их по ней же
# 3. Отправлять в Elastic
# 4. сверять индекс. Если вышла шляпа — попытаться пофиксить (хз как пока, но как вариант второй адрес из выдачи или увеличить ~)
# 5. Добавить критерий оценки качества: если длинна строки большая, а AOLEVEL < 3, то 99% что это дичь

# %% [markdown]
# ## Проверка работоспособности

# %%
cols2 = ['origin',
 'Регион',
 'Район',
 'Город',
 'Н/п',
 'Улица']

# %%
ref  = pd.read_excel('ref/sj.xlsx')
ref2 = pd.read_excel('ref/references.xlsx')

# %%
new_method_mistakes = score(ref2.sample(300))
new_method_mistakes
# Out:
# Working on 1040 of 1040. Progress 100.0%
# 88.5% correct fields
#
# 75.7% correct lines
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#
# 11         р-н         обл        ул            Комсомольская
# 16         р-н         обл        ул                Черемушки
# 376          п           г
# 306        р-н         обл        ул    71 км Киевского шоссе
# 465                    обл        ул                5 Декабря
# 206          п           г
# 111          п           г
# 91                       г         ш               Рублевское
# 156          п           г
# 477                    обл       стр  Овощехранилище 1 бокс 2
# 324          п           г
# 371          п           г
# 145                      г

# %%
Out[354].loc[244].origin
# Out:
# '141200, Российская Федерация, 50 Московская область, Пушкино, Московский проспект, 57'

# %%
standardize(ref2['Исходный адрес'].iloc[random.randint(0, 1040)])
# Out:
# {'address': ', , Россия, Москва г, Новокосинская ул',
#  'house': ', д. 21 , кв. 27 ',
#  'index': None,
#  'origin': ', , Россия, Москва г, Новокосинская ул, д. 21, кв. 27',
#  'Адрес': 'г Москва, ул Новокосинская',
#  'Регион': 'Москва',
#  'Тип региона': 'г',
#  'Тип улицы': 'ул',
#  'Улица': 'Новокосинская'}

# %%
ref2['Исходный адрес'].sample(1).iloc[0]
# Out:
# '125581, Москва г, Ляпидевского ул, д. 2, кв. 9'

# %%
get_addr(ref2['Исходный адрес'])
# Out:
# Working on 1040 of 1040. Progress 100.0%
#                                                 address             house  \
# 0     , Неклиновский р-н х Красный Десант, ,ул Октяб...         ,д. 74  А
# 1          , г Новошахтинск, ,ул Харьковская,д. 14   10
# 2     , г Ростов-на-Дону, ,пр-кт Коммунистический,д....
# 3              , Азовский р-н с Самарское, ,пер Рабочий            ,д. 13
# 4       , Семикаракорский р-н п Вершинный, ,ул Сельская            ,д. 16
# 5     , Октябрьский р-н п Новосветловский, ,пер Доне...            ,д. 14
# 6     , Красносулинский р-н г Красный Сулин, ,ул Бол...       ,д. 4 В  35
# 7                          , г Таганрог, ,ул Акушерская            ,д. 69
# 8         , г Таганрог, ,ул Циолковского,д. 32   2   72
# 9       , Азовский п Тимирязево, ,ул Кольцевя,д. 1   16
# 10               , г Таганрог, ,пер Каркасный,д. 5   31
# 11    , Семикаракорский р-н п Крымский, ,ул Ленина,д...
# 12    , Семикаракорский р-н х Золотаревка, ,ул Октяб...            ,д. 35
# 13    , Октябрьский р-н п Новокадамово, ,ул Гагарина...
# 14             , Веселовский х В-СОЛЕНЫЙ, , ЦЕНТРАЛЬНАЯ            ,д. 64
# 15                          , г с Ряженое, ,пер Чкалова             ,д. 1
# 16       , г Шахты, ,пр-кт Победа Революции,д. 120   44
# 17             , РОСТОВ-НА-ДОНУ, ,  23  ЛИНИЯ,д. 6   20
# 18                             , г Шахты, ,пер Москвина            ,д. 20
# 19                , Сальский р-н г Сальск, ,ул Прогресс            ,д. 20
# 20      , г Азов, ,ул КОТОВА КРАСНОГОРОВСКАЯ,д. 71    9
# 21                                 , г Азов, ,пл Ленина           ,д. 143
# 22    , Азовский р-н г Азов, ,ул Севастопольская,д. ...
# 23            , НОВОЧЕРКАССК, , БУДЕННОВСКАЯ,
# 1027              NaN           Пушкинский       Московская          г
# 1028              NaN                  NaN           Москва        NaN
# 1029              NaN                  NaN           Москва        NaN
# 1030              NaN                  NaN       Московская          г
# 1031              NaN                  NaN           Москва        NaN
# 1032              NaN                  NaN           Москва        NaN
# 1033              NaN                  NaN     Свердловская          г
# 1034              NaN                  NaN     Свердловская          г
# 1035              NaN                  NaN           Москва        NaN
# 1036              NaN                  NaN           Москва        NaN
# 1037              NaN                  NaN           Москва        NaN
# 1038  Лесной проспект                  NaN       Удмуртская          г
# 1039              NaN                  NaN           Москва        NaN
# 1040              NaN                  NaN           Москва        NaN
#
#      Тип н/п Тип района Тип региона Тип улицы                         Улица
# 0          х        р-н         обл        ул                   Октябрьская
# 1        NaN        NaN         обл        ул                   Харьковская
# 2        NaN        NaN         обл     пр-кт              Коммунистический
# 3          с        р-н         обл       пер                       Рабочий
# 4          п        р-н         обл        ул                      Сельская
# 5          п        р-н         обл       пер                      Донецкий
# 6        NaN        р-н         обл        ул                    Больничная
# 7        NaN        NaN         обл        ул                    Акушерская
# 8        NaN        NaN         обл        ул                  Циолковского
# 9          п        р-н         обл        ул                         1 Мая
# 10       NaN        NaN         обл       пер                     Каркасный
# 11         п        р-н         обл        ул                        Ленина
# 12         х        р-н         обл        ул                   Октябрьская
# 13         п        р-н         обл        ул                      Гагарина
# 14         х        р-н        Респ       NaN                           NaN
# 15         с        р-н         обл       пер                       Чкалова
# 16       NaN        NaN         обл     пр-кт              Победа Революции
# 17       NaN        NaN         обл        ул                    23-я линия
# 18       NaN        NaN         обл       пер                      Москвина
# 19       NaN        р-н         обл        ул                      Прогресс
# 20       NaN        NaN         обл        ул               Красногоровская
# 21       NaN        NaN         обл        пл                        Ленина
# 22       NaN        NaN         обл        ул               Севастопольская
# 23       NaN        NaN         обл        ул                  Буденновская
# 24       NaN        р-н         обл        ул                     Димитрова
# 25       NaN        NaN         обл        ул                  Малиновского
# 26       NaN        NaN         обл        ул                 30 лет Победы
# 27       NaN        р-н         обл        ул                Энергетическая
# 28       NaN        NaN         обл        ул                       Котляра
# 29       NaN        NaN         обл        ул                     Оборонная
# ...      ...        ...         ...       ...                           ...
# 1011     NaN        NaN           г         ш                  Измайловское
# 1012     NaN        NaN           г        ул                  Стахановская
# 1013     NaN        NaN         обл       стр       Овощехранилище 1 бокс 2
# 1014     NaN        NaN           г         ш                    Варшавское
# 1015     NaN        NaN           г        ул                    Ферганская
# 1016     NaN        NaN        край       стр                        Гск-86
# 1017     NaN        NaN           г        пл                     Тишинская
# 1018     NaN        NaN        край       тер  ИГСК-607 Николая Островского
# 1019     NaN        NaN           г        пл        Пролетарской Диктатуры
# 1020     тер        NaN         обл       стр                       Бокс 30
# 1021     NaN        NaN           г    проезд                  Библиотечный
# 1022     гск        NaN         обл       NaN                           NaN
# 1023     NaN        NaN           г        ул                         Искры
# 1024     снт        NaN         обл    проезд                          11-й
# 1025       с        р-н        Респ        ул                  Омарова М.О.
# 1026      рп        р-н         обл        ул                       Пушкина
# 1027     NaN        р-н         обл        ул                    Грибоедова
# 1028     NaN        NaN           г     аллея                 Лиственничная
# 1029     NaN        NaN           г     аллея                 Лиственничная
# 1030     NaN        NaN         обл        ул                     Лавочкина
# 1031     NaN        NaN           г       туп                Красносельский
# 1032     NaN        NaN           г        ул                  Каменщики М.
# 1033     NaN        NaN         обл       стр       Овощехранилище 1 бокс 2
# 1034     NaN        NaN         обл       стр       Овощехранилище 1 бокс 2
# 1035     NaN        NaN           г       пер                     Армянский
# 1036     NaN        NaN           г       NaN                           NaN
# 1037     NaN        NaN           г    проезд                  Федосьинский
# 1038     гск        NaN        Респ       NaN                           NaN
# 1039     NaN        NaN           г       пер              Предтеченский М.
# 1040     NaN        NaN           г        ул                      Брянская
#
# [1041 rows x 15 columns]

# %%
ref2['Исходный адрес'][:30]
# Out:
# 0     346841, Неклиновский р-н х Красный Десант, ,ул...
# 1       346900, г Новошахтинск, ,ул Харьковская,д.14 10
# 2     344000, г Ростов-на-Дону, ,пр-кт Коммунистичес...
# 3     346751, Азовский р-н с Самарское, ,пер Рабочий...
# 4     346641, Семикаракорский р-н п Вершинный, ,ул С...
# 5     346480, Октябрьский р-н п Новосветловский, ,пе...
# 6     346352, Красносулинский р-н г Красный Сулин, ,...
# 7               347900, г Таганрог, ,ул Акушерская,д.69
# 8        347900, г Таганрог, ,ул Циолковского,д.32/2 72
# 9     346746, Азовский п Тимирязево, ,ул Кольцевя,д....
# 10            347900, г Таганрог, ,пер Каркасный,д.5 31
# 11    346647, Семикаракорский р-н п Крымский, ,ул Ле...
# 12    346645, Семикаракорский рн х Золотаревка, ,ул ...
# 13    346521, Октябрьский рн п Новокадамово, ,ул Гаг...
# 14    347787, Веселовский х В-СОЛЕНЫЙ, , ЦЕНТРАЛЬНАЯ...
# 15                346974, г с Ряженое, ,пер Чкалова,д.1
# 16    346500, г Шахты, ,пр-кт Победа Революции,д.120 44
# 17            344019, РОСТОВ-НА-ДОНУ, , 23 ЛИНИЯ,д.6 20
# 18                  346503, г Шахты, ,пер Москвина,д.20
# 19     347639, Сальский р-н г Сальск, ,ул Прогресс,д.20
# 20    346780, г Азов, ,ул КОТОВА/КРАСНОГОРОВСКАЯ,д.7...
# 21                     346780, г Азов, ,пл Ленина,д.143
# 22    346780, Азовский р-н г Азов, ,ул Севастопольск...
# 23         346400, НОВОЧЕРКАССК, , БУДЕННОВСКАЯ,д.102 7
# 24        347630, Сальский г Сальск, ,ул Димитрова,д.38
# 25    344000, г Ростов-на-Дону, ,ул Малиновского,д.4...
# 26      347370, г Волгодонск, ,ул 30 лет Победы,д.17 26
# 27    346353, Красносулинский г Красный Сулин, ,ул Э...
# 28                 347924, г Таганрог, ,ул Котляра,д.12
# 29           346906, г Новошахтинск, ,ул Оборонная,д.11
# Name: Исходный адрес, dtype: object

# %%
ref2.iloc[11]['Исходный адрес'].replace('-', '\-')
# Out:
# '346647, Семикаракорский р\\-н п Крымский, ,ул Ленина,д.43 2'

# %%
addrs = []
for i, line in ref2['Исходный адрес'].iteritems():
  address, _ = extract_index(ref2['Исходный адрес'].iloc[random.randint(0, 1040)])
  address, _ = extract_house(address)
  addrs.append(address)
addrs
# Out:
# ['г Шахты, ,ул Искра,',
#  'Москва, , Россия, Москва г, Островитянова ул, ',
#  'Москва г, Новокосинская ул, ',
#  ',  Россия, Москва г, Хлобыстова ул, ',
#  'Российская Федерация, г.Москва ул.Кадомцева ',
#  'ГУКОВО, , ОРДЖОНИКИДЗЕ,',
#  'Москва, , Россия, Москва г, Хачатуряна ул, ',
#  ', , Россия, МОСКОВСКАЯ ОБЛ., ЩЕЛКОВСКИЙ Р-ОН, ЩЕЛКОВО-3, СУПРУНА, ',
#  'Москва г, Фрезер ш, ',
#  'г Шахты, ,ул Заводская,',
#  'Москва, ',
#  'Сальский р-н г Сальск, ,ул Весенняя,',
#  'г Ростов-на-Дону, ,пр-кт Коммунистический,',
#  'Москва, , Россия, Москва г, Литовский б-р, ',
#  'Москва г, Юрьевский пер, ',
#  'г.Москва, ул.Арбат, ',
#  'Московская обл, Подольск г, Давыдова ул, ',
#  'г Ростов-на-Дону, ,ул Малиновского,',
#  'Московская обл, Реутов г, Юбилейный пр-кт, ',
#  'Россия, Москва г, Новозаводская ул, ',
#  'Москва,  ул. Семеновская, ',
#  'г.Москва, улица Шипиловская, ',
#  'Москва, , Россия, Москва г, Полярная ул, ',
#  'г Ростов-на-Дону, ,пер Весенний,',
#  ', , Россия, Москва г, Новокосинская ул, ',
#  'Матвеево-Курганский , Матвеев Курган,ул Шолохова,',
#  'Г. Москва, ул. Ефремова ',
#  ',  Россия, Московская обл, Раменский р-н, Раменское г, Космонавтов ул, ',
#  'Москва, , Россия, Москва г, Матвеевская ул, ',
#  ',  Россия, Московская обл, Воскресенский р-н, Белоозерский пгт, 50 лет Октября ул, ',
#  'Московская обл, Луховицы г, Юбилейная ул, ',
#  'Сальский г Сальск, ,ул Братьев Перн,',
#  'Иное,  КРАСНОДАРСКИЙ КРАЙ, СТ.ДИНСКАЯ, МИРА, ',
#  'АЗОВСКИЙ ПЕШКОВО, , ТЕЛЬМАНА,',
#  'Московская обл',
#  'Москва, , Россия, Москва г, Симоновский Вал ул, ',
#  ', , Россия, Москва г, Домодедовская ул, ',
#  'Волгоград,  ул. Тбилисская, ',
#  'Москва, , Россия, МОСКВА, АК.ЧЕЛОМЕЯ, ',
#  'Москва г, Напрудная 1-я ул, ',
#  ',  Россия, Москва г, Саранская ул, ',
#  ', , Россия, Москва г, Днепропетровская ул, ',
#  'Москва,  Россия, Москва г, Старобитцевская ул, ',
#  'Аксайский , Темерницкий,ул Ветеранов,',
#  'Москва г, Грайвороновская ул, ',
#  'г Ростов-на-Дону, ,ул Российская,',
#  'Москва г, Соловьиный проезд, ',
#  'Москва г, Фрезер ш, ',
#  'Дубовский , Дубовское,пер Восстания,',
#  'г. Москва, Ленинский проспект ',
#  'Красносулинский г Красный Сулин, ,пер Скелеватский 4-й,',
#  'АЗОВ, , ЧЕХОВА,',
#  'Москва г, Старомарьинское ш, ',
#  'Тацинский , Новосуховый,ул Молодежная,',
#  'г Ростов-на-Дону, ,ул Малиновского,',
#  'Москва, , Россия, МОСКВА, АК.ЧЕЛОМЕЯ, ',
#  'Москва г, Совхозная ул, ',
#  'Сальский г Сальск, ,ул Космонавтов,',
#  'г Волгодонск, ,ул Восточная,',
#  'Москва, , Россия, Москва г, Зеленоград г, ',
#  'г. Москва, ул. Академика Королева, ',
#  'г ТАГАНРОГ, ,пер МАРЦЕВСКИЙ,',
#  'Москва г, Москва, Отрадная ул, ',
#  'Санкт-Петербург,  ул. Пролетарской Диктатуры, ',
#  'г. Москва, Смольная, д. 24 «А», оф. 1112',
#  'Сальский р-н г Сальск, ,ул Карла Маркса,',
#  'Московская область,  Россия, Московская обл, Одинцовский р-н, Одинцово г,
#  'Москва г, Чечерский проезд, ',
#  'ГУКОВО, , К МАРКСА,',
#  'г Ростов-на-Дону, ,ул Жмайлова,',
#  'Москва г, Рублевское ш, ',
#  'Москва г, Болотниковская ул, ',
#  'Москва, , Россия, Москва г, Винокурова ул, ',
#  'Москва г, Михайловское с, ',
#  'Москва г, Добролюбова ул, ',
#  'Москва г, Ландышевая ул, ',
#  ', , Россия, Москва г, Новокосинская ул, ',
#  'Российская федерация, Москва, 1-й Голутвинский пер., ',
#  'Московская обл, Балашиха г, ЦОВБ мкр, ',
#  'Санкт-Петербург,  ул. Пролетарской Диктатуры, ',
#  'Москва г, Федеративный пр-кт, ',
#  'Пролетарский , Опенки,ул Садовая,',
#  ', , Россия, Москва г, Красного Маяка ул, ',
#  'Сальский г Сальск, ,ул Смирнова,',
#  'Москва, , Россия, Москва г, Балаклавский пр-кт, ',
#  'Сальский , Рыбасово,ул Труда,',
#  'Москва г, Борисовский проезд, ',
#  'г.Москва, Армянский пер.,',
#  'Москва, , Россия, Москва г, Академика Анохина ул, ',
#  'г. Москва, Предтеченский Верхний пер., ',
#  'Москва, , Россия, Москва г, Зои и Александра Космодемьянских ул, ',
#  'Московская область, , Россия, Московская обл, Щелковский р-н, Щелково г, Шмидта ул, ',
#  'МАТВЕЕВО-КУРГАНСКИЙ МАТВЕЕВ-КУРГАН, , ТАГАНРОГСКАЯ,',
#  'г. Москва, ул. Фридриха Энгельса, ',
#  'г Шахты, ,ул Текстильная,',
#  'Азовский р-н г Азов, ,ул Нагорная,',
#  'Москва г, Горбунова ул, ',
#  'Октябрьский р-н п Новосветловский, ,пер Донецкий,',
#  'Сальский р-н г Сальск, , ,д.',
#  'АЗОВ, , МАКАРОВСКОГО,',
#  'г. Москва, ул. Фридриха Энгельса, ',
#  'Москва г, Новокосинская ул, ',
#  'г.Москва, ул. Новые сады 11-я, ',
#  'Московская обл, Новоивановское рп, Агрохимиков ул, ',
#  ',  Россия, Московская обл, Домодедовский р-н, Чурилково д, ',
#  'Москва г, Рыбинская 3-я ул, ',
#  'г Волгодонск, ,ул 50 лет СССР,',
#  'г ТАГАНРОГ, ,пер МАРЦЕВСКИЙ,',
#  'Москва, , Россия, Москва г, Матвеевская ул, ',
#  'НЕКЛИНОВСКИЙ , , БУДЕННОГО,',
#  ',  Россия, Москва г, Константина Царева ул, ',
#  'г Шахты, ,пер Кирова,',
#  'ТАГАНРОГ, , КАЛИНИНА,',
#  'Москва г, Зеленый пр-кт, ',
#  'Москва г, Борисовский проезд, ',
#  'г ВЕСЕЛЫЙ, ,ул МАЛЫЙ,',
#  'г. Москва, Бережковская наб., ',
#  'г Волгодонск, ,ул Восточная,',
#  'Москва г, Красный Казанец ул, ',
#  ', , Россия, Москва г, Мосфильмовская ул, ',
#  'АЗОВ, , КРАСНОГОРОВСКАЯ,',
#  ', , Россия, Москва г, Осенняя ул, ',
#  'Московская область,  Россия, Московская обл, Мытищинский р-н, Пирогово п, Советская ул, ',
#  'ШАХТЫ, , ЗАРЕЧНАЯ,',
#  'Г. Москва, ул. Кузнецкий Мост, д. 21, 1 подъезд, 3008 офис. Москва,Цветной бульвар, ',
#  'Сальский р-н г Сальск, ,ул Прогресс,',
#  'Москва г, Воротынская ул, ',
#  ', , Россия, Москва г, Волгоградский пр-кт, ',
#  'Москва,  Россия, Москва г, Игральная ул, ',
#  'Азовский р-н , Ново-Александровка,ул Ленина,',
#  'г.Москва,Гостиничный проезд,',
#  'Москва г, Вольская 1-я ул, ',
#  'Москва г, Волгоградский пр-кт, ',
#  'г Волгодонск, ,пл Ленина,',
#  'Москва, , Россия, Москва г, Вострухина ул, ',
#  'Москва, Павелецкая площадь ',
#  'Сальский р-н г Сальск, ,ул Кузнечная,',
#  'Азовский , Кагальник,ул Ленина,',
#  'АЗОВ, , КНИЖНЫЙ,',
#  'Москва, Волгоградский проспект ',
#  'ОКТЯБРЬСКИЙ , , КОМСОМОЛЬСКАЯ,',
#  'г.Москва, ул.Кастанаевская ',
#  'Москва, Леснорядский переулок ',
#  'Московская об-ласть, г.Солнечногорск, ул.Пролетарская, ',
#  'АЗОВ, , МИРНЫЙ,',
#  'Москва г, ул.Перовская, ',
#  'г. Балаково, Саратовской обл., ул. Коммунистическая, ',
#  'Москва,  Россия, МОСКВА, 5 я Парковая, ',
#  'Москва г, Маршала Бирюзова ул, ',
#  'Москва,  Россия, Москва г, Кожевническая ул, ',
#  'г.Москва,Гостиничный проезд,',
#  'г. Москва, ул. Лобачика, ',
#  'Москва г, Маршала Рыбалко ул, ',
#  ',  Россия, Московская область, Балашихинский район, г. Реутов, ул. Советская, ',
#  'г. Москва, Красносельский 1-й пер., ',
#  'НОВОЧЕРКАССК, , ГЕРЦЕНА,',
#  'Московская обл, Химки г, Гоголя ул, ',
#  'Москва г, Сколковское ш, ',
#  'Аксайский , Дорожный,ул Первомайская,',
#  'Московская область,  Россия, Московская обл, Мытищинский р-н, Пирогово п, Советская ул, ',
#  'г. Санкт-Петербург, ул. Новорощинская, ',
#  'г Новочеркасск, ,ул Кавказская,',
#  'Москва, , Россия, Москва г, Генерала Рычагова ул, ',
#  'Московская обл, Пушкино г, Мамонтовка мкр, Мира ул, ',
#  ', , Россия, Москва г, Красного Маяка ул, ',
#  'Москва г, Генерала Глаголева ул, ',
#  'Москва г, Бахрушина ул, ',
#  'Москва, , Россия, Москва г, Ленинский пр-кт, ',
#  'г Азов, ,ул Макаровского,',
#  'Московская обл, Красногорск г, Железнодорожная ул, ',
#  'г. Москва, ул. Дорожная, ',
#  'г Ростов-на-Дону, ,ул ЖДАНОВА,',
#  'Город Москва',
#  ',  Россия, Москва г, Раменки ул, ',
#  'Москва,  МОСКВА, НОВОЧЕРЕМУШКИНСКАЯ, ',
#  'Москва г, Строгинский б-р, ',
#  'Московская область, , Россия, ЛЮБЕРЕЦКИЙ, ЛЫТКАРИНО, ОКТЯБРЬСКАЯ, ',
#  'Зимовниковский , Савоськин,ул Центральная,',
#  'ГУКОВО, , ОРДЖОНИКИДЗЕ,',
#  'Красносулинский р-н , Донлесхоз,ул Ореховая,',
#  'Азовский п Тимирязево, ,ул Кольцевя,',
#  'г Таганрог, ,ул Розы Люксембург,',
#  'г Таганрог, ,ул Чехова,',
#  'Москва, , Россия, Москва г, Ленинский пр-кт, ',
#  'г Таганрог, ,ул Пархоменко,',
#  'Московская область, Домодедовский район, с. Лобаново,  ',
#  'Московская обл, Орехово-Зуево г, Северная ул, ',
#  'Азовский р-н с Самарское, ,пер Рабочий,',
#  'МО, г. Домодедово, Кутузовский пр. ',
#  'Сальский г Сальск, ,ул Космонавтов,',
#  ', , Россия, Москва г, Красного Маяка ул, ',
#  'Московская область, , Россия, Московская, Мытищи, 3-я Крестьянская, ',
#  'Москва, , Россия, Москва г, Янтарный проезд, ',
#  'МО, г. Домодедово, Кутузовский пр. ',
#  'Москва г, Молодежная ул, ',
#  'Российская Федерация, 50 Московская область, Пушкино, Московский проспект, ',
#  'Неклиновский р-н х Красный Десант, ,ул Октябрьская,',
#  'Москва г, ул.Верхняя, д.34 стр.4 - помещение I, ',
#  'Московская обл, Наро-Фоминск г, Рижская ул, ',
#  'Москва,  Россия, МОСКВА, Перовская ул, ',
#  'г Азов, ,ул Макаровского,',
#  ',  Россия, Москва г, Раменки ул, ',
#  'Сальский , Маяк,ул Бедрика,',
#  'Московская область, , Россия, ЛЮБЕРЕЦКИЙ, ЛЫТКАРИНО, ОКТЯБРЬСКАЯ, ',
#  'Москва,  Россия, Москва г, Вилиса Лациса ул, ',
#  'Москва г, Дубнинская ул, ',
#  'Москва г, ул. Лиственничная аллея, ',
#  'Неклиновский , Новобессергеневка,ул Ленина,',
#  'г Таганрог, ,ул Александровская,',
#  'Рязанская обл, Новомичуринск г, ',
#  'АЗОВ, , З.КОСМОДЕМЬЯНСКОЙ,',
#  'АЗОВ, , З.КОСМОДЕМЬЯНСКОЙ,',
#  'Москва, , Россия, Москва г, Зеленодольская ул, ',
#  'г Азов, ,ул Береговая,',
#  'Сальский р-н г Сальск, ,ул Карла Маркса,',
#  'г ТАГАНРОГ, ,пер МАРЦЕВСКИЙ,',
#  'Московская область,  Россия, Московская обл, Одинцовский р-н, Одинцово г, Кутузовская ул, д.',
#  'Москва г, Старобитцевская ул, ',
#  ',  Россия, Москва г, Хлобыстова ул, ',
#  'Москва, , Россия, Москва г, Винокурова ул, ',
#  'г.Москва, ул.Кастанаевская ',
#  'Москва, ул. Брянская, ',
#  'г.Москва, ул. Новые сады 11-я, ',
#  'РОСТОВ-НА-ДОНУ, , 2 Я ПЯТИЛЕТКА,',
#  'Кагальницкий , Кировская,ул Школьная,',
#  'Российская Федерация, 50 Московская область, Пушкино, Московский проспект, ',
#  'г Ростов-на-Дону, ,ул 2-я Краснодарская,',
#  'МОСКВА,  ул. Рязанский, ',
#  'г.Москва, ул.Кастанаевская ',
#  'Москва,  Россия, Москва г, Москва, Скульптора Мухиной ул, ',
#  'г. Москва, Красносельский 1-й пер., ',
#  'Москва,  Россия, Москва г, МОСКВА, Элеваторная ул, ',
#  'Сальский г Сальск, ,ул Трудовая,',
#  'город Москва Проспект Мира ',
#  'Москва,  Россия, Москва, Воротынская, ',
#  'Москва,  ул. Фридриха Энгельса, ',
#  ', , Россия, Московская обл, Подольск г, Парковая ул, ',
#  'Москва г, Маршала Катукова ул, ',
#  'г Новошахтинск, ,ул Харьковская,',
#  'ВОЛГОДОНСК, , 30 ЛЕТ ПОБЕДЫ,',
#  'г Волгодонск, ,ул Восточная,',
#  'Зимовниковский , Савоськин,ул Центральная,',
#  'Москва г, Палехская ул, ',
#  'Москва,  ул. Смольная, ',
#  'Москва г, Черняховского ул, ',
#  'БАТАЙСК, , ВОРОВСКОГО,',
#  'г.Москва,Гостиничный проезд,',
#  'Москва г, Дубнинская ул, ',
#  'Московская область,  Россия, Московская обл, Одинцовский р-н, Одинцово г, Солнечная ул, ',
#  'Москва,  ул. Авиамоторная, ',
#  'Москва,  Россия, Москва г, Борисовский проезд, ',
#  'Московская обл, Люберцы г, Электрификации ул, ',
#  'Московская область,  Россия, Московская обл, Жуковский г, Чкалова ул, ',
#  ',  Россия, Московская обл, Балашихинский р-н, Балашиха г, Объединения ул, ',
#  'Российская Федерация, Г. Москва, -, Василия Петушкова ул, ',
#  'Москва, Павелецкая площадь ',
#  'Москва,  ул. Фридриха Энгельса, ',
#  ', , Россия, Московская обл, Подольск г, Парковая ул, ',
#  'Республика Коми, г. Сыктывкар, ул Карла Маркса, ',
#  'АЗОВ, , МОСКОВСКАЯ,',
#  'Московская обл, Химки г, 9 Мая ул, ',
#  'Московская обл, Реутов г, Юбилейный пр-кт, ',
#  'г Ростов-на-Дону, ,пл Королева,',
#  'Московская обл, Одинцово г, Глазынинская ул, ',
#  'Москва,Пресненская набережная 8 стр.1 Бизнес-центр "Москва-Сити", башня "Город столиц", 15 этаж Северной башни',
#  'МО, г. Домодедово, Кутузовский пр. ',
#  'Московская обл, Наро-Фоминск г, Рижская ул, ',
#  'Москва г, Вилиса Лациса ул, ',
#  'Усть-Донецкий , Раздорская,ул Октябрьская,',
#  'Неклиновский , Синявское,ул Ленина,',
#  'Люберцы ул. Красная ',
#  'Москва г, Старобитцевская ул, ',
#  'г Батайск, ,ул Энгельса,',
#  'Московская область, г. Красногорск, ул. 50 лет Октября, ',
#  'Российская Федерация, г. Москва, Бориса Галушкина ул., ',
#  'Москва,  МОСКОВСКАЯ, БАЛАШИХА, МОСКОВСКИЙ Б-Р, ',
#  'г Таганрог, ,ул Циолковского,',
#  'АЗОВ, , МОСКОВСКАЯ,',
#  'г. Москва, 1-ый Можайский тупик, ',
#  'Московская обл, Подольск г, Давыдова ул, ',
#  'Москва, , Россия, Москва г, Ленинский пр-кт, ',
#  'г АЗОВ, ,ул З. КОСМОДЕМЬЯНСКОЙ,',
#  'г Новошахтинск, ,ул Краснооктябрьская,',
#  'Москва,  ул. Изумрудная, ',
#  'Неклиновский , Федоровка,ул Семашко,',
#  'Московская обл, Домодедово г, Агрохимик снт, ',
#  'Страна: Российская Федерация; ОКАТО: 45263579000; Почтовый индекс: 111672; Субъект РФ: Москва; Улица: Суздальская; ',
#  'Москва г, Шипиловская ул, ',
#  'Дагестан Респ, Кизляр г, Куйбышева ул, ',
#  'ШАХТЫ, , ЧЕХОВА,',
#  'Аксайский , Грушевская,ул Советская,',
#  'Москва, , Россия, Москва г, Дмитровское ш, ',
#  'БАТАЙСК, , НЕФТЕГОРСКАЯ,',
#  'Москва,  Россия, Москва г, Вилиса Лациса ул, ',
#  'Московская область, , Россия, МОСКОВСКАЯ ОБЛАСТЬ, СЕРПУХОВСКИЙ, ДЕР.МИХАЙЛОВКА, ОПЕРАТОРА, ',
#  'Брянск,  ул. Костычева, ',
#  'Москва,  Россия, -, Москва, Авиамоторная, ',
#  'Красносулинский р-н , Донлесхоз,ул Ореховая,',
#  'Москва,  ул. Ферганская, ',
#  'Москва, , Россия, Москва г, Зеленоград г, ',
#  ', , Россия, МОСКОВСКАЯ, РЕУТОВ, ПР-Т ЮБИЛЕЙНЫЙ, ',
#  'Москва,  Россия, Москва г, Хибинский проезд, ',
#  'Московская обл, Луховицы г, Юбилейная ул, ',
#  'Российская Федерация, г. Москва, Москва, проезд Рощинский 4-й, ',
#  'Москва,  Россия, Москва г, МОСКВА, Элеваторная ул, ',
#  ', , Россия, Москва г, Кировоградская ул, ',
#  ',  Россия, Москва г, Смирновская ул, ',
#  'г Шахты, ,пер Луговой,',
#  'г ВЕСЕЛЫЙ, ,ул МАЛЫЙ,',
#  'Московская обл, Балашиха г, ЦОВБ мкр, ',
#  'Москва г, Костякова ул, ',
#  'г. Пермь, ул. Куйбышева ',
#  'г Ростов-на-Дону, ,ул Зорге,',
#  'МО, г.Коломна, ул.Октябрьской революции, ',
#  'Российская Федерация, г.Москва ул.Кадомцева ',
#  ',  Россия, Москва г, Хлобыстова ул, ',
#  'Московская обл, Пушкино г, Клязьма мкр, Крыловская ул, ',
#  'г Азов, ,ул Береговая,',
#  'г Таганрог, ,ул Чехова,',
#  'Ростовская область, г. Таганрог, пер Комсомольский, ',
#  'г Ростов-на-Дону, ,ул Города Волос,',
#  'Сальский р-н г Сальск, ,ул Карла Маркса,',
#  'НОВОЧЕРКАССК, , ТРОИЦКАЯ,',
#  'г Волгодонск, ,ул 50 лет СССР,',
#  'г.Новосибирск, ул.Советская, ',
#  'Москва г, Вешняковская ул, ',
#  'Сальский , Конезавод имени Буденного,ул Театральная,',
#  'Москва г, Воротынская ул, ',
#  'Москва г, Смирновская ул, ',
#  ', , Россия, МОСКОВСКАЯ ОБЛ., ЩЕЛКОВСКИЙ Р-ОН, ЩЕЛКОВО-3, СУПРУНА, ',
#  'РОСТОВ-НА-ДОНУ, , БОРКО,',
#  ',  Россия, Москва г, Саранская ул, ',
#  ',  Россия, Московская обл, Воскресенский р-н, Белоозерский пгт, 50 лет Октября ул, ',
#  'Иное, , Россия, Челябинская обл, Челябинск г, Энтузиастов ул, ',
#  'Москва г, Планетная ул, ',
#  'г Таганрог, ,ул Ткаченко,',
#  'Москва,  Россия, Москва, Большоя Филёвская, ',
#  'г Таганрог, ,ул Котляра,',
#  'Москва,  Россия, МОСКВА, 5 я Парковая, ',
#  'Москва,  ул. Варшавское, ',
#  'Азовский р-н , Ново-Александровка,ул Ленина,',
#  'Москва, , Россия, Москва г, Нагатинская наб, ',
#  ', , Россия, Москва г, Живописная ул, ',
#  'Матвеево-Курганский , Матвеев Курган,ул Шолохова,',
#  ',  Россия, Москва г, Саранская ул, ',
#  'г Шахты, ,пер Иртышский,',
#  'МОСКВА,  ул. Климентовский , ',
#  'Неклиновский р-н , Покровское,ул Пионерская,',
#  ...]

# %%
a=random.choice(addrs)
a
# Out:
# ', , Россия, Москва, Москва, Новочеремушкинска, '

# %%
a
# Out:
# ', , Россия, Москва, Москва, Новочеремушкинска, '

# %%
len(addrs)
# Out:
# 1041

# %%
# Out:
# Working on 14 of 1040. Progress 1.3%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 484 of 1040. Progress 46.5%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.011s]
# Working on 606 of 1040. Progress 58.3%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.015s]
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.017s]
# Working on 661 of 1040. Progress 63.6%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.006s]
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 803 of 1040. Progress 77.2%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 828 of 1040. Progress 79.6%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.014s]
# Working on 864 of 1040. Progress 83.1%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.011s]
# Working on 878 of 1040. Progress 84.4%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.006s]
# Working on 926 of 1040. Progress 89.0%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.007s]
# Working on 965 of 1040. Progress 92.8%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.009s]
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.009s]
# Working on 978 of 1040. Progress 94.0%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.007s]
# Working on 1029 of 1040. Progress 98.9%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 1040 of 1040. Progress 100.0%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-568-567557ef8431> in <module>()
# ----> 1 score(get_addr(ref2['Исходный адрес']).fillna(''), ref2.fillna(''))
#
# <ipython-input-567-01b27d8f21e8> in score(df_1, ref)
#      15           correct += 1
#      16         else:
# ---> 17           df.add(df_1[i])
#      18   return correct/n*100, pd.DataFrame(df)
#
# TypeError: unhashable type: 'dict'

# %%
Out
# Out:
# {9: [],
#  10: ['корпус'],
#  11: ['офис'],
#  12: ['дом'],
#  16: {'а': {'литера'},
#   'б': {'литера'},
#   'в': {'литера'},
#   'вл': {'владение'},
#   'владение': {'владение'},
#   'д': {'дом'},
#   'дом': {'дом'},
#   'е': {'литера'},
#   'к': {'корпус'},
#   'кабинет': {'квартира'},
#   'кв': {'квартира'},
#   'квартира': {'квартира'},
#   'ком': {'комната'},
#   'комн': {'комната'},
#   'комната': {'комната'},
#   'копр': {'корпус'},
#   'кор': {'корпус'},
#   'корп': {'корпус'},
#   'корпус': {'корпус'},
#   'лит': {'прочее'},
#   'литер': {'прочее'},
#   'литера': {'прочее'},
#   'оф': {'офис'},
#   'офис': {'офис'},
#   'пом': {'помещение'},
#   'помещение': {'помещение'},
#   'с': {'строение'},
#   'стр': {'строение'},
#   'строен': {'строение'},
#   'строение': {'строение'}},
#  17: {'литера'},
#  18: {'владение'},
#  24: {'а': {'литера'},
#   'б': {'литера'},
#   'в': {'литера'},
#   'вл': {'дом'},
#   'г': {'город'},
#   'гор': {'город'},
#   'город': {'город'},
#   'д': {'дом'},
#   'д-ня': {'деревня'},
#   'дер': {'деревня'},
#   'деревня': {'деревня'},
#   'дом': {'дом'},
#   'инд': {'индекс'},
#   'индекс': {'индекс'},
#   'к': {'корпус'},
#   'кабинет': {'квартира'},
#   'кв': {'квартира'},
#   'квартира': {'квартира'},
#   'ком': {'квартира'},
#   'комн': {'квартира'},
#   'комната': {'квартира'},
#   'копр': {'корпус'},
#   'кор': {'корпус'},
#   'корп': {'корпус'},
#   'корпус': {'корпус'},
#   'оф': {'офис'},
#   'офис': {'офис'},
#   'пом': {'квартира'},
#   'помещение': {'квартира'},
#   'поселок': {'с/п'},
#   'с': {'корпус'},
#   'сел': {'село'},
#   'село': {'село'},
#   'сельский': {'с/п'},
#   'сп': {'с/п'},
#   'стр': {'корпус', 'страна'},
#   'страна': {'страна'},
#   'строен': {'корпус'},
#   'строение': {'корпус'}},
#  25: {'город': {'город': {'г', 'гор', 'город'},
#    'деревня': {'д', 'д-ня', 'дер', 'деревня'},
#    'с/п': {'поселок', 'сельский', 'сп'},
#    'село': {'с', 'сел', 'село'}},
#   'дом': {'дом': {'вл', 'д', 'дом'},
#    'квартира': {'кабинет',
#     'кв',
#     'квартира',
#     'ком',
#     'комн',
#     'комната',
#     'пом',
#     'помещение'},
#    'корпус': {'к',
#     'копр',
#     'кор',
#     'корп',
#     'корпус',
#     'с',
#     'стр',
#     'строен',
#     'строение'},
#    'литера': {'а', 'б', 'в'},
#    'офис': {'оф', 'офис'}},
#   'индекс': {'инд', 'индекс'},
#   'страна': {'стр', 'страна'}},
#  26: {'а': {'литера'},
#   'б': {'литера'},
#   'в': {'литера'},
#   'вл': {'дом'},
#   'г': {'город'},
#   'гор': {'город'},
#   'город': {'город'},
#   'д': {'дом'},
#   'д-ня': {'деревня'},
#   'дер': {'деревня'},
#   'деревня': {'деревня'},
#   'дом': {'дом'},
#   'инд': {'индекс'},
#   'индекс': {'индекс'},
#   'к': {'корпус'},
#   'кабинет': {'квартира'},
#   'кв': {'квартира'},
#   'квартира': {'квартира'},
#   'ком': {'квартира'},
#   'комн': {'квартира'},
#   'комната': {'квартира'},
#   'копр': {'корпус'},
#   'кор': {'корпус'},
#   'корп': {'корпус'},
#   'корпус': {'корпус'},
#   'оф': {'офис'},
#   'офис': {'офис'},
#   'пом': {'квартира'},
#   'помещение': {'квартира'},
#   'поселок': {'с/п'},
#   'с': {'корпус'},
#   'сел': {'село'},
#   'село': {'село'},
#   'сельский': {'с/п'},
#   'сп': {'с/п'},
#   'стр': {'корпус', 'страна'},
#   'страна': {'страна'},
#   'строен': {'корпус'},
#   'строение': {'корпус'}},
#  30: {'а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'к', 'л', 'м', 'н', 'о'},
#  34: False,
#  36: {'владение'},
#  37: {'владение'},
#  39: {'владение'},
#  43: ['Москва', ',', 'улица', 'Большая', 'Татарска', ',', '35'],
#  49: ['Москва', ',', 'улица', 'Большая', 'Татарска', ',', '35'],
#  51: ['Москва', ',', 'улица', 'Большая', 'Татарска', ',', '35'],
#  52: ['число'],
#  53: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['не распознано'],
#   ['препинания'],
#   ['число']],
#  55: ['число'],
#  56: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['не распознано'],
#   ['препинания'],
#   ['число']],
#  60: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   'у',
#   'л',
#   'и',
#   'ц',
#   'а',
#   ['не распознано'],
#   ['препинания'],
#   ['число']],
#  63: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['улица'],
#   ['препинания'],
#   ['число']],
#  65: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['улица'],
#   ['препинания'],
#   ['число']],
#  66: ['число'],
#  67: ['МОСКВА',
#   ',',
#   '109542',
#   ',',
#   'ул',
#   'Рязанский',
#   ',',
#   'д',
#   '86',
#   '1',
#   ',',
#   'стр',
#   '3',
#   ',',
#   'оф',
#   '6',
#   'а'],
#  68: ['не распознано'],
#  69: ['число'],
#  70: [['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['не распознано'],
#   ['препинания'],
#   ['число']],
#  71: [['не распознано'],
#   ['препинания'],
#   ['индекс'],
#   ['препинания'],
#   ['не распознано'],
#   ['не распознано'],
#   ['препинания'],
#   ['не распознано'],
#   ['число'],
#   ['число'],
#   ['препинания'],
#   ['не распознано'],
#   ['число'],
#   ['препинания'],
#   ['не распознано'],
#   ['число'],
#   ['не распознано']],
#  72: ['не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'дом'},
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'строение'},
#   'не распознано',
#   'не распознано',
#   {'офис'},
#   'не распознано',
#   {'литера'}],
#  73: ['не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'дом'},
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'строение'},
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'литера'}],
#  74: ['не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'дом'},
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'строение'},
#   'не распознано',
#   'не распознано',
#   {'офис'},
#   'не распознано',
#   {'литера'}],
#  75: [<function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'дом'},
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'строение'},
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'офис'},
#   <function __main__.<listcomp>.<lambda>>,
#   {'литера'}],
#  77: 'число',
#  78: 'не распознано',
#  79: [<function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'дом'},
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'строение'},
#   <function __main__.<listcomp>.<lambda>>,
#   <function __main__.<listcomp>.<lambda>>,
#   {'офис'},
#   <function __main__.<listcomp>.<lambda>>,
#   {'литера'}],
#  80: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'дом'},
#   'число',
#   'число',
#   'не распознано',
#   {'строение'},
#   'число',
#   'не распознано',
#   {'офис'},
#   'число',
#   {'литера'}],
#  81: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   {'дом'},
#   'число',
#   'число',
#   'не распознано',
#   {'строение'},
#   'число',
#   'не распознано',
#   {'офис'},
#   'число',
#   {'литера'}],
#  82: {'а': {'литера'},
#   'б': {'литера'},
#   'в': {'литера'},
#   'вл': {'владение'},
#   'владение': {'владение'},
#   'д': {'дом'},
#   'дом': {'дом'},
#   'е': {'литера'},
#   'к': {'корпус'},
#   'кабинет': {'квартира'},
#   'кв': {'квартира'},
#   'квартира': {'квартира'},
#   'ком': {'комната'},
#   'комн': {'комната'},
#   'комната': {'комната'},
#   'копр': {'корпус'},
#   'кор': {'корпус'},
#   'корп': {'корпус'},
#   'корпус': {'корпус'},
#   'лит': {'прочее'},
#   'литер': {'прочее'},
#   'литера': {'прочее'},
#   'оф': {'офис'},
#   'офис': {'офис'},
#   'пом': {'помещение'},
#   'помещение': {'помещение'},
#   'с': {'строение'},
#   'стр': {'строение'},
#   'строен': {'строение'},
#   'строение': {'строение'}},
#  88: {'а': 'литера',
#   'б': 'литера',
#   'в': 'литера',
#   'вл': 'дом',
#   'г': 'город',
#   'гор': 'город',
#   'город': 'город',
#   'д': 'дом',
#   'д-ня': 'деревня',
#   'дер': 'деревня',
#   'деревня': 'деревня',
#   'дом': 'дом',
#   'инд': 'индекс',
#   'индекс': 'индекс',
#   'к': 'корпус',
#   'кабинет': 'квартира',
#   'кв': 'квартира',
#   'квартира': 'квартира',
#   'ком': 'квартира',
#   'комн': 'квартира',
#   'комната': 'квартира',
#   'копр': 'корпус',
#   'кор': 'корпус',
#   'корп': 'корпус',
#   'корпус': 'корпус',
#   'оф': 'офис',
#   'офис': 'офис',
#   'пом': 'квартира',
#   'помещение': 'квартира',
#   'поселок': 'с/п',
#   'с': 'корпус',
#   'сел': 'село',
#   'село': 'село',
#   'сельский': 'с/п',
#   'сп': 'с/п',
#   'стр': ['корпус', 'страна'],
#   'страна': 'страна',
#   'строен': 'корпус',
#   'строение': 'корпус'},
#  90: {'а': 'литера',
#   'б': 'литера',
#   'в': 'литера',
#   'вл': 'владение',
#   'владение': 'владение',
#   'г': 'литера',
#   'д': ['дом', 'литера'],
#   'дом': 'дом',
#   'е': 'литера',
#   'ж': 'литера',
#   'з': 'литера',
#   'к': ['корпус', 'квартира'],
#   'к-т': 'кабинет',
#   'каб': 'кабинет',
#   'каб-т': 'кабинет',
#   'кабинет': 'кабинет',
#   'кв': 'квартира',
#   'квартира': 'квартира',
#   'ком': 'комната',
#   'комн': 'комната',
#   'комната': 'комната',
#   'копр': 'корпус',
#   'кор': 'корпус',
#   'корп': 'корпус',
#   'корпус': 'корпус',
#   'лит': 'прочее',
#   'литер': 'прочее',
#   'литера': 'прочее',
#   'оф': 'офис',
#   'офис': 'офис',
#   'пом': 'помещение',
#   'помещение': 'помещение',
#   'с': 'строение',
#   'стр': 'строение',
#   'строен': 'строение',
#   'строение': 'строение'},
#  91: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   ['дом', 'литера'],
#   'число',
#   'число',
#   'не распознано',
#   'строение',
#   'число',
#   'не распознано',
#   'офис',
#   'число',
#   'литера'],
#  94: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   ['дом', 'литера'],
#   'число',
#   'число',
#   'не распознано',
#   'строение',
#   'число',
#   'не распознано',
#   'офис',
#   'число',
#   'литера'],
#  96: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   ['дом', 'литера'],
#   'число',
#   'число',
#   'не распознано',
#   'строение',
#   'число',
#   'не распознано',
#   'офис',
#   'число',
#   'литера'],
#  100: {'а': 'литера',
#   'б': 'литера',
#   'в': 'литера',
#   'вл': 'владение',
#   'владение': 'владение',
#   'д': 'дом',
#   'дом': 'дом',
#   'е': 'литера',
#   'ж': 'литера',
#   'з': 'литера',
#   'к': 'корпус',
#   'к-т': 'кабинет',
#   'каб': 'кабинет',
#   'каб-т': 'кабинет',
#   'кабинет': 'кабинет',
#   'кв': 'квартира',
#   'квартира': 'квартира',
#   'ком': 'комната',
#   'комн': 'комната',
#   'комната': 'комната',
#   'копр': 'корпус',
#   'кор': 'корпус',
#   'корп': 'корпус',
#   'корпус': 'корпус',
#   'лит': 'прочее',
#   'литер': 'прочее',
#   'литера': 'прочее',
#   'оф': 'офис',
#   'офис': 'офис',
#   'пом': 'помещение',
#   'помещение': 'помещение',
#   'с': 'строение',
#   'стр': 'строение',
#   'строен': 'строение',
#   'строение': 'строение'},
#  101: ['не распознано',
#   'не распознано',
#   'число',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'не распознано',
#   'дом',
#   'число',
#   'число',
#   'не распознано',
#   'строение',
#   'число',
#   'не распознано',
#   'офис',
#   'число',
#   'литера'],
#  121: ['не распознано',
#   'препинания',
#   'число',
#   'препинания',
#   'не распознано',
#   'не распознано',
#   'препинания',
#   'дом',
#   'число',
#   'число',
#   'препинания',
#   'строение',
#   'число',
#   'препинания',
#   'офис',
#   'число',
#   'литера'],
#  125: ['не распознано',
#   'препинания',
#   'не распознано',
#   'препинания',
#   'не распознано',
#   'не распознано',
#   'препинания',
#   'дом',
#   'число',
#   'число',
#   'препинания',
#   'строение',
#   'число',
#   'препинания',
#   'офис',
#   'число',
#   'литера'],
#  132: [(12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0)],
#  142: <function dict.keys>,
#  143: dict_keys(['д', 'дом', 'владение', 'вл', 'к', 'копр', 'кор', 'корпус', 'корп', 'стр', 'строен', 'с', 'строение', 'квартира', 'кв', 'помещение', 'пом', 'комн', 'ком', 'комната', 'кабинет', 'каб', 'каб-т', 'к-т', 'оф', 'офис', 'ж', 'а', 'е', 'в', 'б', 'з', 'литера', 'литер', 'лит']),
#  144: dict_keys,
#  145: dict_keys(['д', 'дом', 'владение', 'вл', 'к', 'копр', 'кор', 'корпус', 'корп', 'стр', 'строен', 'с', 'строение', 'квартира', 'кв', 'помещение', 'пом', 'комн', 'ком', 'комната', 'кабинет', 'каб', 'каб-т', 'к-т', 'оф', 'офис', 'ж', 'а', 'е', 'в', 'б', 'з', 'литера', 'литер', 'лит']),
#  146: True,
#  147: False,
#  148: ['бяка'],
#  151: [(12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0)],
#  152: [(12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0)],
#  153: [(12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0)],
#  154: [(1, 2)],
#  155: [(11, -3)],
#  156: {-5, -4, -3},
#  157: [(12, 0), (13, 0), (14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0)],
#  158: [(1, 2)],
#  160: [(4, 3)],
#  161: [(4, 3), (5, 3), (6, 3)],
#  163: [(14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0), (20, 0), (21, 0)],
#  167: [(14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0), (20, 0), (21, 0)],
#  176: [(14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0), (20, 0), (21, 0)],
#  177: [(4, 3), (5, 3), (6, 3)],
#  179: [(4, 3), (5, 3), (6, 3)],
#  181: ['86', '1'],
#  183: ['86', '1'],
#  185: [(4, 3), (5, 3), (6, 3)],
#  186: ['86', '1'],
#  191: [',', 'д', '86', '1', ',', 'стр', '3', ',', 'оф', '6', 'а'],
#  198: ['МОСКВА',
#   ',',
#   '109542',
#   ',',
#   'ул',
#   'Рязанский',
#   ',',
#   'Д',
#   '86',
#   '1',
#   ',',
#   'стр',
#   '3',
#   ',',
#   'оф',
#   '6',
#   'а'],
#  199: <_sre.SRE_Match object; span=(20, 36), match='дом 3 строение 5'>,
#  200: <function SRE_Match.start>,
#  201: 20,
#  202: <_sre.SRE_Match object; span=(20, 36), match='дом 3 строение 5'>,
#  214: [(4, 3), (5, 3), (6, 3)],
#  244: ('Улица карамольская', ', Дом 3 Строение 5'),
#  247: ('Улица карамольская', ', Дом 3 Строение 5'),
#  253: {'а': 'литера',
#   'б': 'литера',
#   'в': 'литера',
#   'вл': 'владение',
#   'владение': 'владение',
#   'д': 'дом',
#   'дом': 'дом',
#   'е': 'литера',
#   'ж': 'литера',
#   'з': 'литера',
#   'к': 'корпус',
#   'к-т': 'кабинет',
#   'каб': 'кабинет',
#   'каб-т': 'кабинет',
#   'кабинет': 'кабинет',
#   'кв': 'квартира',
#   'квартира': 'квартира',
#   'ком': 'комната',
#   'комн': 'комната',
#   'комната': 'комната',
#   'копр': 'корпус',
#   'кор': 'корпус',
#   'корп': 'корпус',
#   'корпус': 'корпус',
#   'лит': 'прочее',
#   'литер': 'прочее',
#   'литера': 'прочее',
#   'оф': 'офис',
#   'офис': 'офис',
#   'пом': 'помещение',
#   'помещение': 'помещение',
#   'с': 'строение',
#   'стр': 'строение',
#   'строен': 'строение',
#   'строение': 'строение'},
#  290:                                                 address  \
#  0     Неклиновский р-н х Красный Десант, ,ул Октябрь...
#  1                       г Новошахтинск, ,ул Харьковская
#  2             г Ростов-на-Дону, ,пр-кт Коммунистический
#  3                Азовский р-н с Самарское, ,пер Рабочий
#  4         Семикаракорский р-н п Вершинный, ,ул Сельская
#  5      Октябрьский р-н п Новосветловский, ,пер Донецкий
#  6     Красносулинский р-н г Красный Сулин, ,ул Больн...
#  7                            г Таганрог, ,ул Акушерская
#  8                          г Таганрог, ,ул Циолковского
#  9                   Азовский п Тимирязево, ,ул Кольцевя
#  10                           г Таганрог, ,пер Каркасный
#  11           Семикаракорский р-н п Крымский, ,ул Ленина
#  12    Семикаракорский р-н х Золотаревка, ,ул Октябрь...
#  13         Октябрьский р-н п Новокадамово, ,ул Гагарина
#  14               Веселовский х В-СОЛЕНЫЙ, , ЦЕНТРАЛЬНАЯ
#  15                            г с Ряженое, ,пер Чкалова
#  16                     г Шахты, ,пр-кт Победа Революции
#  17                           РОСТОВ-НА-ДОНУ, , 23 ЛИНИЯ
#  18                               г Шахты, ,пер Москвина
#  19                  Сальский р-н г Сальск, ,ул Прогресс
#  20                   г Азов, ,ул КОТОВА/КРАСНОГОРОВСКАЯ
#  21                                   г Азов, ,пл Ленина
#  22             Азовский р-н г Азов, ,ул Севастопольская
#  23                         НОВОЧЕРКАССК, , БУДЕННОВСКАЯ
#  24                     Сальский г Сальск, ,ул Димитрова
#  25                   г Ростов-на-Дону, ,ул Малиновского
#  26                      г Волгодонск, ,ул 30 лет Победы
#  27    Красносулинский г Красный Сулин, ,ул Энергетич...
#  28                              г Таганрог, ,ул Котляра
#  29                        г Новошахтинск, ,ул Оборонная
#  ...                                                 ...
#  1011                          Москва,  ул. Измайловское
#  1012                         г.Москва, ул. Стахановская
#  1013                           Москва,  ул. Семеновская
#  1014                            Москва,  ул. Варшавское
#  1015                            Москва,  ул. Ферганская
#  1016                             МОСКВА,  ул. Рязанский
#  1017                             Москва,  ул. Тишинская
#  1018                           Казань,  ул. Островского
#  1019       Санкт-Петербург,  ул. Пролетарской Диктатуры
#  1020                                             Москва
#  1021                   Москва,  ул. Проезд Библиотечный
#  1022    Московская область, г. Химки, ул. Ленинградская
#  1023                                Москва,  ул. Искры
Азов, ,ул КОТОВА/КРАСНОГОРОВСКАЯ,д.7...
#  21                     346780, г Азов, ,пл Ленина,д.143
#  22    346780, Азовский р-н г Азов, ,ул Севастопольск...
#  23         346400, НОВОЧЕРКАССК, , БУДЕННОВСКАЯ,д.102 7
#  24        347630, Сальский г Сальск, ,ул Димитрова,д.38
#  25    344000, г Ростов-на-Дону, ,ул Малиновского,д.4...
#  26      347370, г Волгодонск, ,ул 30 лет Победы,д.17 26
#  27    346353, Красносулинский г Красный Сулин, ,ул Э...
#  28                 347924, г Таганрог, ,ул Котляра,д.12
#  29           346906, г Новошахтинск, ,ул Оборонная,д.11
#  ...                                                 ...
#  1011            Москва, 105318, ул. Измайловское, д. 20
#  1012    109428, г.Москва, ул. Стахановская, д.17, стр.1
#  1013  Москва, 105094, ул. Семеновская, д. 2/1, стр. ...
#  1014       Москва, 117105, ул. Варшавское, д. 1, стр. 6
#  1015  Москва, 109444, ул. Ферганская, д. 15, стр. 2,...
#  1016  МОСКВА, 109542, ул. Рязанский, д. 86/1, стр. 3...
#  1017        Москва, 123056, ул. Тишинская, д. 1, стр. 1
#  1018    Казань, 420107, ул. Островского, д. 84, оф. 607
#  1019  Санкт-Петербург, 191124, ул. Пролетарской Дикт...
#  1020                                    Москва, стр. 30
#  1021  Москва, 125599, ул. Проезд Библиотечный, д. 1А...
#  1022  141400, Московская область, г. Химки, ул. Лени...
#  1023    Москва, 129344, ул. Искры , д. 31 корп.1, оф. 5
#  1024  119619, г.Москва, ул. Новые сады 11-я, д.2, стр.1
#  1025  141280, М.О., г.Ивантеевка, ул. Дзержинского, д.1
#  1026  141231, ул. Московская область, Пушкинский рай...
#  1027  Московская область Пушкино, 141200, ул. Грибое...
#  1028  127550, Москва г, ул. Лиственничная аллея,, д....
#  1029  127550, Москва г, ул. Лиственничная аллея, д. ...
#  1030  Российская Федерация, 141407, Московская обл.,...
#  1031  107140, г. Москва, Красносельский 1-й пер., д....
#  1032  115172, Москва г, ул.Большие Каменщики, д.1 - 414
#  1033           119002, г.Москва, ул.Арбат, д.54/2 стр.1
#  1034  Российская федерация, Москва, 1-й Голутвинский...
#  1035            101990,г.Москва, Армянский пер.,д.9/1/1
#  1036                            129626, Москва, а/я 158
#  1037  115191, Российская Федерация, г. Москва, Москв...
#  1038         109428, г.Москва, Рязанский проспект, д.10
#  1039  123242, г. Москва, Предтеченский Верхний пер.,...
#  1040                    121059, Москва, ул. Брянская, 3
#
#  [1041 rows x 4 columns],
#  295: {'address': 'Москва, , Россия, Москва г, Шверника ул',
#   'house': ', д. 12, к. 2, стр. 3, кв. 46',
#   'index': None,
#   'origin': 'Москва, , Россия, Москва г, Шверника ул, д. 12, к. 2, стр. 3, кв. 46'},
#  297: {'address': 'г. Волгоград, ул. Мира',
#   'house': ', д. 21, кв. 48.',
#   'index': None,
#   'origin': 'г. Волгоград, ул. Мира, д. 21, кв. 48.'},
#  303: {'aolevel': '7',
#   'fullname': 'г Москва, ул Лобачика',
#   'guid': 'd5a06adc-bc61-4d2e-a43e-91f6154ebaba',
#   'region': 'Москва',
#   'region_type': 'г',
#   'street': 'Лобачика',
#   'street_type': 'ул'},
#  304: {'address': 'г москва, ул Лобачика ',
#   'house': 'д 4 к 5',
#   'index': None,
#  660  Москва,  117105 , ул. Нагорный, д.  10 , стр.  7
#  663   129085 , г. Москва, Звездный бульвар, дом  3 ...
#  664   119049 , г. Москва, Ленинский проспект  4  ко...
#  668  Москва,  105094 , ул. Семеновская, д.  2   1 ,...
#  671  МОСКВА,  109542 , ул. Рязанский, д.  86   1 , ...
#  674  Казань,  420107 , ул. Островского, д.  84 , оф...
#  677  Санкт-Петербург,  191124 , ул. Пролетарской Ди...
#  678                                  Москва, стр.  30
#  682   141400 , Московская область, г. Химки, ул. Ле...
#  684   119619 , г.Москва, ул. Новые сады  11 -я, д. ...
#  688   141280 , М.О., г.Ивантеевка, ул. Дзержинского...
#  693   107140 , г. Москва, Красносельский  1 -й пер....
#  694   115172 , Москва г, ул.Большие Каменщики, д. 1...
#  695    119002 , г.Москва, ул.Арбат, д. 54   2  стр. 1
#  698  Российская федерация, Москва,  1 -й Голутвинск...
#  701   115191 , Российская Федерация, г. Москва, Мос...
# ...
#  17                        ,д.6 20  344019
#  18                          ,д.20  346503
#  19                          ,д.20  347639
#  20                       ,д.71/ 9  346780
#  21                         ,д.143  346780
#  22                      ,д.27 103  346780
#  23                       ,д.102 7  346400
#  24                          ,д.38  347630
#  25                      ,д.44 Б 2  344000
#  26                       ,д.17 26  347370
#  27                           ,д.7  346353
#  28                          ,д.12  347924
#  29                          ,д.11  346906
#  ...                           ...     ...
#  1011                      , д. 20  105318
#  1012                , д.17, стр.1  109428
#  1013      , д. 2/1, стр. 1, оф. 1  105094
#  1014               , д. 1, стр. 6  117105
#  1015       , д. 15, стр. 2, оф. 3  109444
#  1016    , д. 86/1, стр. 3, оф. 6а  109542
#  1017               , д. 1, стр. 1  123056
#  1018             , д. 84, оф. 607  420107
#  1019  , д. 6, стр. лит.А, оф. 322  191124
#  1020                    , стр. 30    None
#  1021              , д. 1А, стр. 7  125599
#  1022                      , д. 29  141400
#  1023        , д. 31 корп.1, оф. 5  129344
#  1024                 , д.2, стр.1  119619
#  1025                        , д.1  141280
#  1026                      , д.8-б  141231
#  1027              , д. 7, оф. 407  141200
#  1028           ,, д.д. 12, стр. 4  127550
#  1029              , д. 12, стр. 4  127550
#  1030         13, корп. 1, офис 92  141407
#  1031       , д.3, пом.1, комн. 79  107140
#  1032                               115172
#  1033               , д.54/2 стр.1  119002
#  1034            , д. 2/10, стр. 1    None
#  1035                     ,д.9/1/1  101990
#  1036                    , а/я 158  129626
#  1037                         , 15  115191
#  1038                       , д.10  109428
#  1039             , д. 11А, стр. 3  123242
#  1040                          , 3  121059
#
#                                                   origin
#  0     346841, Неклиновский р-н х Красный Десант, ,ул...
#  1       346900, г Новошахтинск, ,ул Харьковская,д.14 10
#  2     344000, г Ростов-на-Дону, ,пр-кт Коммунистичес...
# 12      Золотаревка      Семикаракорский       Ростовская        NaN       х
# 13     Новокадамово          Октябрьский       Ростовская        NaN       п
# 14          Соленый          Ишимбайский     Башкортостан        NaN       х
# 15          Ряженое  Матвеево-Курганский       Ростовская        NaN       с
# 16              NaN                  NaN       Ростовская          г     NaN
# 17              NaN                  NaN       Ростовская          г     NaN
# 18              NaN                  NaN       Ростовская          г     NaN
# 19              NaN             Сальский       Ростовская          г     NaN
#
#    Тип района Тип региона Тип улицы             Улица
# 0         р-н         обл        ул       Октябрьская
# 1         NaN         обл        ул       Харьковская
# 2         NaN         обл     пр-кт  Коммунистический
# 3         р-н         обл       пер           Рабочий
# 4         р-н         обл        ул          Сельская
# 5         р-н         обл       пер          Донецкий
# 6         р-н         обл        ул        Больничная
# 7         NaN         обл        ул        Акушерская
# 8         NaN         обл        ул      Циолковского
# 9         р-н         обл       NaN               NaN
# 10        NaN         обл       пер         Каркасный
# 11        р-н         обл        ул            Ленина
# 12        р-н         обл        ул       Октябрьская
# 13        р-н         обл        ул          Гагарина
# 14        р-н        Респ       NaN               NaN
# 15        р-н         обл       пер           Чкалова
# 16        NaN         обл     пр-кт  Победа Революции
# 17        NaN         обл        ул        23-я линия
# 18        NaN         обл       пер          Москвина
# 19        р-н         обл        ул          Прогресс

# %%
ref2[:20]
# Out:
#                                        Исходный адрес  \
# 0   346841, Неклиновский р-н х Красный Десант, ,ул...
# 1     346900, г Новошахтинск, ,ул Харьковская,д.14 10
# 2   344000, г Ростов-на-Дону, ,пр-кт Коммунистичес...
# 3   346751, Азовский р-н с Самарское, ,пер Рабочий...
# 4   346641, Семикаракорский р-н п Вершинный, ,ул С...
# 5   346480, Октябрьский р-н п Новосветловский, ,пе...
# 6   346352, Красносулинский р-н г Красный Сулин, ,...
# 7             347900, г Таганрог, ,ул Акушерская,д.69
# 8      347900, г Таганрог, ,ул Циолковского,д.32/2 72
# 9   346746, Азовский п Тимирязево, ,ул Кольцевя,д....
# 10          347900, г Таганрог, ,пер Каркасный,д.5 31
# 11  346647, Семикаракорский р-н п Крымский, ,ул Ле...
# 12  346645, Семикаракорский рн х Золотаревка, ,ул ...
# 13  346521, Октябрьский рн п Новокадамово, ,ул Гаг...
# 14  347787, Веселовский х В-СОЛЕНЫЙ, , ЦЕНТРАЛЬНАЯ...
# 15              346974, г с Ряженое, ,пер Чкалова,д.1
# 16  346500, г Шахты, ,пр-кт Победа Революции,д.120 44
# 17          344019, РОСТОВ-НА-ДОНУ, , 23 ЛИНИЯ,д.6 20
# 18                346503, г Шахты, ,пер Москвина,д.20
# 19   347639, Сальский р-н г Сальск, ,ул Прогресс,д.20
#
#                                                 Адрес    Индекс  Страна  \
# 0   Ростовская обл, Неклиновский р-н, х Красный Де...  346844.0  Россия
# 1   Ростовская обл, г Новошахтинск, ул Харьковская...  346900.0  Россия
# 2   г Ростов-на-Дону, пр-кт Коммунистический, д 43...  344091.0  Россия
# 3   Ростовская обл, Азовский р-н, с Самарское, пер...  346751.0  Россия
# 11             NaN       п         Крымский        NaN          NaN        ул
# 12             NaN       х      Золотаревка        NaN          NaN        ул
# 13             NaN       п     Новокадамово        NaN          NaN        ул
# 14             NaN       х    Верхнесоленый        NaN          NaN        ул
# 15             NaN       с          Ряженое        NaN          NaN       пер
# 16           Шахты     NaN              NaN        NaN          NaN     пр-кт
# 17  Ростов-на-Дону     NaN              NaN        NaN          NaN        ул
# 18           Шахты     NaN              NaN        NaN          NaN       пер
# 19          Сальск     NaN              NaN        NaN          NaN        ул
#
#                Улица Тип дома   Дом Тип корпуса/строения Корпус/строение  \
# 0        Октябрьская        д   74А                  NaN             NaN
# 1        Харьковская        д    14                  NaN             NaN
# 2   Коммунистический        д    43                  NaN             NaN
# 3            Рабочий        д    13                  NaN             NaN
# 4           Сельская        д    16                  NaN             NaN
# 5           Донецкий        д    14                  NaN             NaN
# 6         Больничная        д    4В                  NaN             NaN
# 7         Акушерская        д    69                  NaN             NaN
# 8       Циолковского        д  32/2                  NaN             NaN
# 9          Кольцевая        д     1                  NaN             NaN
# 10         Каркасный        д     5                  NaN             NaN
# 11            Ленина        д    43                  NaN             NaN
# 12       Октябрьская        д    35                  NaN             NaN
# 13          Гагарина        д    20                  NaN             NaN
# 14       Центральная        д    64                  NaN             NaN
# 15           Чкалова        д     1                  NaN             NaN
# 16  Победа Революции        д   120                  NaN             NaN
# 17        23-я линия        д     6                  NaN             NaN
# 18          Москвина        д    20                  NaN             NaN
# 19          Прогресс        д    20                  NaN             NaN
#
#    Тип квартиры Номер Квартиры
# 0           NaN            NaN
# 1            кв             10
# 2            кв            165
# 3           NaN            NaN
# 4           NaN            NaN
# 5           NaN            NaN
# 6            кв             35
# 7           NaN            NaN
# 8            кв             72
# 9            кв             16
# 10           кв             31
# 11           кв              2
# 12          NaN            NaN
# 13           кв              4
# 14          NaN            NaN
# 15          NaN            NaN
# 16           кв             44
# 17           кв             20
# 18          NaN            NaN
# 19          NaN            NaN

# %%
ref3 = ref2.sample(1000)
score(get_addr(ref3['Исходный адрес']).fillna(''), ref3.fillna(''))[cols2]
# Out:
# Working on 42 of 999. Progress 4.2%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.033s]
# Working on 57 of 999. Progress 5.7%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.006s]
# Working on 108 of 999. Progress 10.8%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.004s]
# Working on 491 of 999. Progress 49.1%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 636 of 999. Progress 63.7%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.011s]
# Working on 962 of 999. Progress 96.3%
# WARNING:elasticsearch:GET http://localhost:9200/fias_full_text/address/_search [status:400 request:0.005s]
# Working on 999 of 999. Progress 100.0%
# 94.1%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-278-43bae2e6bdd3> in <module>()
#       1 ref3 = ref2.sample(1000)
# ----> 2 score(get_addr(ref3['Исходный адрес']).fillna(''), ref3.fillna(''))[cols2]
#
# NameError: name 'cols2' is not defined

# %%
ref3.iloc[280]
# Out:
# Исходный адрес          344114, г Ростов-на-Дону, ,ул Орбитальная,д.54...
# Адрес                      г Ростов-на-Дону, ул Орбитальная, д 54, кв 100
# Индекс                                                             344114
# Страна                                                             Россия
# Тип региона                                                           обл
# Регион                                                         Ростовская
# Тип района                                                            NaN
# Район                                                                 NaN
# Тип города                                                              г
# Город                                                      Ростов-на-Дону
# Тип н/п                                                               NaN
# Н/п                                                                   NaN
# Адм. округ                                                            NaN
# Район города                                                          NaN
# Тип улицы                                                              ул
# Улица                                                         Орбитальная
# Тип дома                                                                д
# Дом                                                                    54
# Тип корпуса/строения                                                  NaN
# Корпус/строение                                                       NaN
# Тип квартиры                                                           кв
# Номер Квартиры                                                        100
# Name: 208, dtype: object

# %%
old_method = get_addr(ref2['Исходный адрес'])
# Out:
# Working on 1040 of 1040. Progress 100.0%

# %%
cols = ['Исходный адрес',
 'Регион',
 'Район',
 'Город',
 'Н/п',
 'Адм. округ',
 'Район города',
 'Улица']

# %%
# %timeit verify_address(" г ТАГАНРОГ, ,ул Б. БУЛЬВАРНАЯ", debug=True)
# Out:
# 20.8 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
ref3.iloc[16]
# Out:
# Исходный адрес                  346512, г Шахты, ,пер Цуканова,д.25
# Адрес                   Ростовская обл, г Шахты, пер Цуканова, д 25
# Индекс                                                       346512
# Страна                                                       Россия
# Тип региона                                                     обл
# Регион                                                   Ростовская
# Тип района                                                      NaN
# Район                                                           NaN
# Тип города                                                        г
# Город                                                         Шахты
# Тип н/п                                                         NaN
# Н/п                                                             NaN
# Адм. округ                                                      NaN
# Район города                                                    NaN
# Тип улицы                                                       пер
# Улица                                                      Цуканова
# Тип дома                                                          д
# Дом                                                              25
# Тип корпуса/строения                                            NaN
# Корпус/строение                                                 NaN
# Тип квартиры                                                    NaN
# Номер Квартиры                                                  NaN
# Name: 86, dtype: object

# %%
shortables = {
  "малая":{"м", "мал", "м-я", "малая"},
  "большая":{"б", "бол", "б-я", "большая"},
  "малый":{"м", "мал", "м-й", "малый"},
  "средний":{"с", "ср", "ср-ий", "ср-й", "средний"},
  "большой":{"б", "бол", "б-й", "большой"},
}
def fuzzy_street_size(string):
  
  return

# %%
def inverdic(dic):
  resdic = {}
  for key, value in dic.items():
    for index in value:
      if type(value) == set or type(value) == list:
        if index in resdic.keys():
          if isinstance(resdic[index], set):
            resdic[index].add(key)
          elif isinstance(resdic[index], list):
            resdic[index].append(key)
          else:
            resdic[index] = [resdic[index]]
            resdic[index].append(key)
        else:
          resdic[index] = key
      elif type(value) == dict:
        resdic.update(inverdic(value))
  return resdic

# %%
types = {
  'город':{
    'город':{'г', 'гор', 'город'},
    'село':{'с', 'село', 'сел'},
    'деревня':{'д', 'дер', 'деревня', 'д-ня'},
    'с/п':{"сельский", "поселок", "сп"}
  },
  'дом':{
    'дом': {'вл', 'д', 'дом'},
    'корпус': {'к', 'корп', 'копр', 'кор', 'корпус', 'с', 'стр', 'строен', 'строение'},
    'квартира': {'кабинет', 'кв', 'квартира', "ком",'комн', 'пом', 'помещение', 'комната'},
    'офис': {'оф', 'офис'},
    'литера': {'а', 'б', 'в'}
  },
  'страна':{'страна', 'стр'},
  'индекс':{'индекс', 'инд'}
}

# %%
inverdic(types)
# Out:
# {'а': 'литера',
#  'б': 'литера',
#  'в': 'литера',
#  'вл': 'дом',
#  'г': 'город',
#  'гор': 'город',
#  'город': 'город',
#  'д': 'дом',
#  'д-ня': 'деревня',
#  'дер': 'деревня',
#  'деревня': 'деревня',
#  'дом': 'дом',
#  'инд': 'индекс',
#  'индекс': 'индекс',
#  'к': 'корпус',
#  'кабинет': 'квартира',
#  'кв': 'квартира',
#  'квартира': 'квартира',
#  'ком': 'квартира',
#  'комн': 'квартира',
#  'комната': 'квартира',
#  'копр': 'корпус',
#  'кор': 'корпус',
#  'корп': 'корпус',
#  'корпус': 'корпус',
#  'оф': 'офис',
#  'офис': 'офис',
#  'пом': 'квартира',
#  'помещение': 'квартира',
#  'поселок': 'с/п',
#  'с': 'корпус',
#  'сел': 'село',
#  'село': 'село',
#  'сельский': 'с/п',
#  'сп': 'с/п',
#  'стр': ['корпус', 'страна'],
#  'страна': 'страна',
#  'строен': 'корпус',
#  'строение': 'корпус'}

# %%
shortables.update(inverdic(shortables))

# %%
inverdic(shortables)
# Out:
# {'б': {'большая', 'большой'},
#  'б-й': {'большой'},
#  'б-я': {'большая'},
#  'бол': {'большая', 'большой'},
#  'большая': {'большая'},
#  'большой': {'большой'},
#  'м': {'малая', 'малый'},
#  'м-й': {'малый'},
#  'м-я': {'малая'},
#  'мал': {'малая', 'малый'},
#  'малая': {'малая'},
#  'малый': {'малый'},
#  'с': {'средний'},
#  'ср': {'средний'},
#  'ср-ий': {'средний'},
#  'ср-й': {'средний'},
#  'средний': {'средний'}}

# %%
{**shortables, **inverdic(shortables)}
# Out:
# {'б': {'большая', 'большой'},
#  'б-й': {'большой'},
#  'б-я': {'большая'},
#  'бол': {'большая', 'большой'},
#  'большая': {'большая'},
#  'большой': {'большой'},
#  'м': {'малая', 'малый'},
#  'м-й': {'малый'},
#  'м-я': {'малая'},
#  'мал': {'малая', 'малый'},
#  'малая': {'малая'},
#  'малый': {'малый'},
#  'с': {'средний'},
#  'ср': {'средний'},
#  'ср-ий': {'средний'},
#  'ср-й': {'средний'},
#  'средний': {'средний'}}

# %%
shortables
# Out:
# {'б': {'большая', 'большой'},
#  'б-й': {'большой'},
#  'б-я': {'большая'},
#  'бол': {'большая', 'большой'},
#  'большая': {'б', 'б-я', 'бол', 'большая'},
#  'большой': {'б', 'б-й', 'бол', 'большой'},
#  'м': {'малая', 'малый'},
#  'м-й': {'малый'},
#  'м-я': {'малая'},
#  'мал': {'малая', 'малый'},
#  'малая': {'м', 'м-я', 'мал', 'малая'},
#  'малый': {'м', 'м-й', 'мал', 'малый'},
#  'с': {'средний'},
#  'ср': {'средний'},
#  'ср-ий': {'средний'},
#  'ср-й': {'средний'},
#  'средний': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'}}

# %%
inverdic(shortables)
# Out:
# {'большая': {'б', 'б-я', 'бол', 'большая'},
#  'большой': {'б', 'б-й', 'бол', 'большой'},
#  'малая': {'м', 'м-я', 'мал', 'малая'},
#  'малый': {'м', 'м-й', 'мал', 'малый'},
#  'средний': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'}}

# %%
shortables.update(inverdic(shortables))

# %%
shortables
# Out:
# {'б': {'большая', 'большой'},
#  'б-й': {'большой'},
#  'б-я': {'большая'},
#  'бол': {'большая', 'большой'},
#  'большая': {'б', 'б-я', 'бол', 'большая'},
#  'большой': {'б', 'б-й', 'бол', 'большой'},
#  'м': {'малая', 'малый'},
#  'м-й': {'малый'},
#  'м-я': {'малая'},
#  'мал': {'малая', 'малый'},
#  'малая': {'м', 'м-я', 'мал', 'малая'},
#  'малый': {'м', 'м-й', 'мал', 'малый'},
#  'с': {'средний'},
#  'ср': {'средний'},
#  'ср-ий': {'средний'},
#  'ср-й': {'средний'},
#  'средний': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'}}

# %%
def fill(dic):
  newdic = dict()
  for key, value in dic.items():
    newdic[key] = value
    for item in value:
      try:
        newdic[item].add(key)
      except KeyError:
        newdic[item] = {key, *value}
  return newdic

# %%
fill(shortables)
# Out:
# {'б': {'б', 'б-я', 'бол', 'большая', 'большой'},
#  'б-й': {'б', 'б-й', 'бол', 'большой'},
#  'б-я': {'б', 'б-я', 'бол', 'большая'},
#  'бол': {'б', 'б-я', 'бол', 'большая', 'большой'},
#  'большая': {'б', 'б-я', 'бол', 'большая'},
#  'большой': {'б', 'б-й', 'бол', 'большой'},
#  'м': {'м', 'м-я', 'мал', 'малая', 'малый'},
#  'м-й': {'м', 'м-й', 'мал', 'малый'},
#  'м-я': {'м', 'м-я', 'мал', 'малая'},
#  'мал': {'м', 'м-я', 'мал', 'малая', 'малый'},
#  'малая': {'м', 'м-я', 'мал', 'малая'},
#  'малый': {'м', 'м-й', 'мал', 'малый'},
#  'с': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'},
#  'ср': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'},
#  'ср-ий': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'},
#  'ср-й': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'},
#  'средний': {'с', 'ср', 'ср-ий', 'ср-й', 'средний'}}

# %%
shortables = {'б': {'б', 'большая', 'большой'},
 'б-й': {'б', 'большой'},
 'б-я': {'б', 'большая'},
 'бол': {'б', 'большая', 'большой'},
 'большая': {'б', 'большая'},
 'большой': {'б', 'большой'},
 'м': {'м', 'малая', 'малый'},
 'м-й': {'м', 'малый'},
 'м-я': {'м', 'малая'},
 'мал': {'м', 'малая', 'малый'},
 'малая': {'м', 'малая'},
 'малый': {'м', 'малый'},
 'с': {'с', 'ср', 'средний'},
 'ср': {'с', 'ср', 'средний'},
 'ср-ий': {'с', 'ср', 'средний'},
 'ср-й': {'с', 'ср', 'средний'},
 'средний': {'с', 'ср', 'средний'}}

# %%
# %%timeit 
for key in shortables.keys():
  key in "Москва, улица Большая Татарска, 35"
# Out:
# 1.29 µs ± 11.2 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %out 582
# Out:
# UsageError: Line magic function `%out` not found.

# %%
verify_address('МОСКВА, пр. Рязанский',  debug=True)
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '36b4d93f-38cd-4b02-9d0d-c005f14e38eb',
#     '_index': 'fias_full_text',
#     '_score': 20.72171,
#     '_source': {'aolevel': '7',
#      'fullname': 'г Москва, пр-кт Рязанский',
#      'guid': '36b4d93f-38cd-4b02-9d0d-c005f14e38eb',
#      'region': 'Москва',
#      'region_type': 'г',
#      'street': 'Рязанский',
#      'street_type': 'пр-кт'},
#     '_type': 'address'}],
#   'max_score': 20.72171,
#   'total': 17199},
#  'timed_out': False,
#  'took': 10}

# %%
ref2["Исходный адрес"].iloc[1016]
# Out:
# 'МОСКВА, 109542, ул. Рязанский, д. 86/1, стр. 3, оф. 6а'

# %%
[map_types(x) for x in tokenize(ref3['Исходный адрес'].iloc[random.randint(0, 1040)])]

# %%
print(1)
# Out:
# 1

# %%
search_dict("д", dic=sep_house_signs)
# Out:
# ['дом']

# %%
set("абвгдежзиклмно")
# Out:
# {'а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'к', 'л', 'м', 'н', 'о'}

# %%
map_types()
check_num()
tokenize()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-8e165977b4fd> in <module>()
# ----> 1 map_types()
#
# TypeError: map_types() missing 1 required positional argument: 'token'

# %%
tokenize('МОСКВА, 109542, ул. Рязанский, Д. 86/1, стр. 3, оф. 6а', comma=True)
# Out:
# ['МОСКВА',
#  ',',
#  '109542',
#  ',',
#  'ул',
#  'Рязанский',
#  ',',
#  'Д',
#  '86',
#  '1',
#  ',',
#  'стр',
#  '3',
#  ',',
#  'оф',
#  '6',
#  'а']

# %%
check_num([map_types(x) for x in Out[67]], -2)
# Out:
# ['число']

# %%
[house_signs_inv.get(x, a(x)) for x in Out[67]]
# Out:
# ['не распознано',
#  'препинания',
#  'не распознано',
#  'препинания',
#  'не распознано',
#  'не распознано',
#  'препинания',
#  'дом',
#  'число',
#  'число',
#  'препинания',
#  'строение',
#  'число',
#  'препинания',
#  'офис',
#  'число',
#  'литера']

# %%
for i, _ in enumerate(Out[67]):
  print(Out[67][i], " ==> ", Out[125][i])
# Out:
# МОСКВА  ==>  не распознано
# ,  ==>  препинания
# 109542  ==>  не распознано
# ,  ==>  препинания
# ул  ==>  не распознано
# Рязанский  ==>  не распознано
# ,  ==>  препинания
# д  ==>  дом
# 86  ==>  число
# 1  ==>  число
# ,  ==>  препинания
# стр  ==>  строение
# 3  ==>  число
# ,  ==>  препинания
# оф  ==>  офис
# 6  ==>  число
# а  ==>  литера

# %%
a = lambda x: "число" if x.isdigit() and len(x)<6 else "препинания" if x == ',' else "не распознано"

# %%
def longest_seq(A, item):
  array = (list(y) for (x,y) in itertools.groupby((enumerate(A)),operator.itemgetter(1)) if x == item)
  a = max(array, key=len)
  print(a)

# %%
longest_seq([1,2,0,0,3, 3, 3, 4,5,-1,0,2,-1,-3,0,0,0,0,0,0,0,0,2,-3,-4,-5,0,0,0], 0)
# Out:
# [(14, 0), (15, 0), (16, 0), (17, 0), (18, 0), (19, 0), (20, 0), (21, 0)]

# %%
# %timeit extract_house(Out[67])
# Out:
# 18.6 µs ± 1.21 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# берём длиннейшую последовательность распознанного с приоритетом того что ближе к концу

# %%
set([-3, -4, -5])
# Out:
# {-5, -4, -3}

# %%
a[4] = ["улица"]

# %%
a
# Out:
# [['не распознано'],
#  ['препинания'],
#  ['не распознано'],
#  ['не распознано'],
#  ['улица'],
#  ['препинания'],
#  ['число']]

# %%
re.search('дом 3 строение 5', "Улица карамольская, Дом 3 Строение 5")

# %%
extract_house("Улица карамольская, Дом 3 Строение 5")
# Out:
# ('Улица карамольская', ', Дом 3 Строение 5')

# %%
max(reversed([[2, 4], [3], [4, 6]]), key=len)
# Out:
# [4, 6]
