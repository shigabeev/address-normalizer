# %%
import pandas as pd
import re

# %% [markdown]
# ## Основные методы

# %%
def tokenize(string, comma=False):
  for stopword in {r'\n', r'\r'}:
    string = string.replace(stopword, '')
  string = re.sub(r"[\d]+", ' \g<0> ', string)
  if not comma:
    return re.findall(r'\w+(?:-\w+)+|[\w]+', str.lower(string))
  else:
    return re.findall(r'\w+(?:-\w+)+|[\w]+|\,', str.lower(string))

# %%
def diff_sets(set1, set2, silent = False):
  '''
  Удаляет из set1 значения set2
  Возвращает что осталось от set1
  '''
  set3 = set1.copy()
  n = 0
  for value in set1:
    if value in set2:
      set3.remove(value)
      n+=1
  if not silent:
    print('Удалено {0} записей'.format(n))
  return set3

def whole_set(set_name):
  if isinstance(set_name, set) or isinstance(set_name, list):
    return set_name.copy()
  elif isinstance(set_name, dict):
    result = {}
    for key, value in set_name.items():
      try:
        result.update(whole_set(value))
      except ValueError:
        result = whole_set(value)
    return result
  
def remove(array, element):
  '''
  Удаляет элемент из массива если он там существует. Не понятно почему родной метод работает по-другому.
  '''
  if element in array:
    array.remove(element)

# %% [markdown]
# ## Методы для загрузки словаря

# %%
def load_types():
  sep_region_signs = {
    'обл.': {"область", "обл", "обл-ть", 'МО'},
    'респ.': {"республика", 'респ'},
    'край': {'край'},
    'город': {'г', 'гор', 'город'},
    'АО':{'ао', 'автономный', 'округ', 'автономная'}
  }

  sep_street_signs = {
    'аллея':{'аллея', 'а'},
    'бульвар':{'б-р', 'бульвар', 'б'}, #- надо добавлять special case
    'наб.':{'наб', 'набережная'},
    'переулок':{'пер', 'переулок'},
    'площадь':{'пл', "площадь"},
    "проспект":{"пр", "пр-кт", "просп"},
    "проезд":{"проезд", "пр-д"},
    "ул.":{"улица", "ул", "у", 'ул-ца'}
  }

  sep_district_signs = {
    'р-н':{'район', "р" , "р-н"},
    'п':{'п', 'пгт', 'поселок', "посёлок", "городского", "типа"}
  }

  sep_city_signs  = {
    'город':{'г', 'гор', 'город'},
    'село':{'с', 'село', 'сел'},
    'деревня':{'д', 'дер', 'деревня', 'д-ня'},
    'с/п':{"сельский", "поселок", "сп"}
  }

  sep_house_signs = {
    'дом': {'вл', 'д', 'дом'},
    'корпус': {'к', 'корп', 'копр', 'кор', 'корпус', 'с', 'стр', 'строен', 'строение'},
    'квартира': {'кабинет', 'кв', 'квартира', "ком",'комн', 'пом', 'помещение', 'комната'},
    'офис': {'оф', 'офис'},
    'литера': {'а', 'б', 'в'}
  }
  
  types = {
    'город':sep_city_signs,
    'дом':sep_house_signs,
    'улица':sep_street_signs,
    'район':sep_district_signs,
    'регион':sep_region_signs,
    'страна':{'страна', 'стр'},
    'индекс':{'индекс', 'инд'}
  }
  
  return types

# %%
def load_cities():
  # https://maps.vlasenko.net/russia/ru-list.csv
  long_cities = pd.read_excel('cities.xlsx', header=None)
  long_cities.columns = ['region', 'district', 'town', 'x', 'y']
  cities_list = []
  for tokens in long_cities['town'].apply(tokenize):
    cities_list.extend(tokens)
  return set(cities_list)

# %%
def load_regions():
  regions_list = pd.read_excel('regions.xlsx')
  sep_regions_list = {}
  for line in regions_list.itertuples():
    try:
      sep_regions_list[line[3]].update({token for token in tokenize(line[2])})
    except KeyError:
      sep_regions_list[line[3]]={token for token in tokenize(line[2])}
  return sep_regions_list

# %%
def load_streets():
  Streets = pd.read_csv('streets.tsv', sep='\t')
  streetset=['парканат', 'вознесенское']
  for tokens in Streets['Парканат (Вознесенское)'].astype(str).apply(tokenize):
    streetset.extend(tokens)
  return set(streetset)

# %%
def load_names():
  names = {
    'улица':load_streets(),
    'город':load_cities(),
    'регион':load_regions(),
    'страна':{
      'россия':{"россия", "российская", "федерация", "рф"},
      'беларусь':{"белоруссия", "беларусь"},
      'украина':{"украина"}
    }
  }
  return names

# %%
def load_vocabulary(vocab = 'vocab.json'):
  import json
  try:
    with open(vocab, 'r') as fs:
      vocabulary = to_set(json.load(fs))
      return vocabulary
  except FileNotFoundError:
    pass
  
  vocabulary = {
    'типы': load_types(),
    'названия': load_names(),
    'препинания':{',', '-', '.', '/'}
  }
  
  ###
  ###    Теперь надо их очистить друг от друга
  ###
  
  # Города федерального значения считаются регионами
  for a in ['москва', 'санкт-петербург', 'севастополь']:
    try:
      vocabulary['названия']['город'].remove(a)
    except:
      pass
  
  # самые замусореные словари - это города и улиц, так как они черпаются из ФИАС
  for name in ['город', 'улица']:
    for that_type in ['улица', "дом", "район", "регион", "город", 'страна', 'индекс']:
      vocabulary['названия'][name] = diff_sets(vocabulary['названия'][name], whole_set(vocabulary['типы'][that_type]))

  vocabulary['названия']['улица'].remove('россия')
  vocabulary['названия']['улица'].remove('москва')
  vocabulary['названия']['улица'].update('б')
  
  return vocabulary

# %%
def save_vocab(vocabulary, name = 'vocab.json'):
  import json
  class SetEncoder(json.JSONEncoder):
    def default(self, obj):
      if isinstance(obj, set):
         return list(obj)
      return json.JSONEncoder.default(self, obj)
  with open(name, 'w') as fs:
    json.dump(vocabulary, fs, cls=SetEncoder)

# %%
def to_set(nested_dict):
  if isinstance(nested_dict, dict):
    new_dict = nested_dict.copy()
    for key, value in nested_dict.items():
       new_dict[key] = to_set(value)
    return new_dict
  elif isinstance(nested_dict, list):
    return set(nested_dict)
  elif isinstance(nested_dict, set):
    return nested_dict

# %%
# %time vocabulary = load_vocabulary()
# Out:
# Удалено 4 записей
# Удалено 4 записей
# Удалено 2 записей
# Удалено 2 записей
# Удалено 3 записей
# Удалено 1 записей
# Удалено 0 записей
# Удалено 19 записей
# Удалено 16 записей
# Удалено 9 записей
# Удалено 12 записей
# Удалено 5 записей
# Удалено 1 записей
# Удалено 2 записей
# CPU times: user 44 s, sys: 511 ms, total: 44.5 s
# Wall time: 45.2 s

# %%
save_vocab(vocabulary)

# %% [markdown]
# ## Стандартизация адреса

# %% [markdown]
# Стандартизация происходит по 20 полям как в ДаДате. Составим табличку поиска

# %%
LUT = {    # Look-up-table
  'типы':{
    'город':7,
    'дом':{
        'дом': 15,
        'корпус': 17,
        'квартира': 19,
        'офис': 19,
        'литера': 30},
    'улица':13,
    'район':5,
    'регион':3,
    'страна':32,
    'индекс':31
  },
  'названия':{
    'улица':14,
    'город':8,
    'страна':2,
    'район':4,
    'регион':4
  },
  'препинания':0
}

# %%
def titles_():
  target_fields = ['Запятая', 'Индекс', 'Страна', 'Тип региона',
                 'Регион', 'Тип района', 'Район',
                 'Тип города', 'Город', 'Тип н/п',
                 'Н/п', 'Адм. округ', 'Район города',
                 'Тип улицы', 'Улица', 'Тип дома', 'Дом',
                 'Тип корпуса/строения', 'Корпус/строение',
                 'Тип квартиры', 'Номер Квартиры', 'Не распознано', 'число']
  dic = {}
  for i in range(len(target_fields)):
    dic[i] = target_fields[i]
  dic[30] = 'литера'
  dic[31] = 'обозначение индекса'
  dic[32] = 'обозначение страны'
  return dic

# %%
titles = titles_()

# %% [markdown]
# ### Вспомогательные методы

# %%
def set_intersect(set1, set2):
  """
  Возвращает общие значения двух сетов
  """
  set3 = []
  for i in set1:
    if i in set2:
      set3.append(i)
  return set(set3)

# %%
def map_types(token):
  ''' Возвращает номер класса '''
  if token == ',':
    return [0]
  elif token.isdigit():
    if is_index(token): 
      return [1]
    elif len(str(token))>6:
      return [21]
    else: 
      return [22]
  else:
    possible_types = decode_dict(search_dict(token, vocabulary))
    if len(possible_types) == 1:
      return possible_types
    elif len(possible_types) > 1:
      return possible_types
    else:
      return [21]

# %% [markdown]
# ### Самый главный и самый лагучий детектор

# %%
def clear_street(types):
  '''
  Определяется с названием улицы. 
  После того как определится — удаляет это городое звание со всех остальных ячеек, оставляя меньше вариантов.
  '''
  # находит последовательность типов, обзывает её улицей и говорит что все остальные это точно не улица
  signs = get_index(types, 13)
  streets = get_index(types, 14)
  signs.extend(streets)
  # самая длительная последовательность объявляется победителем
  curr_length = 0 
  max_length = 0
  items = []
  if signs == []:
    signs = streets
  
  for i in signs:
    # go right
    j = i
    curr_length = 0
    while j<len(types) and (14 in types[j] or 13 in types[j]):
      curr_length += 1
      if curr_length >= max_length:
        max_length = curr_length
        items = list(range(i,j+1))
      j += 1
    
    # go left
    j = i
    curr_length = 0
    while j>0 and (14 in types[j] or 13 in types[j]):
      curr_length += 1
      if curr_length >= max_length:
        max_length = curr_length
        items = list(range(j, i+1))
      j -= 1
  
  # теперь оставляем звание улицы только за выбранной последовательностью
  for i, element in enumerate(types):
    if 14 in element and i not in items:
      if len(element)>1:
        types[i].remove(14)
      else:
        types[i] = [21]
    elif 13 in element and i in items:
      types[i] = [13]
    elif 14 in element and i in items:
      types[i] = [14]
  return types

def is_index(string):
  if len(string)!=6:
    return False
  return string.isdigit()

def check_num(types, i):
  '''
  Этот детектор определяет что из чисел является номером дома, что номером квартиры итд
  '''
  if i-1>=0:
    if 0 in types[i-1] and i-2>0 and (14 in types[i-2] or 13 in types[i-2]):
      return [16]
    if 15 in types[i-1]:
      types[i-1] = [15]
      return [16]
    elif 17 in types[i-1]:
      types[i-1] = [17]
      return [18]
    elif 19 in types[i-1]:
      types[i-1] = [19]
      return [20]
    elif 14 in types[i-1]:
      types[i-1] = [14]
      return [16]
#     elif 13 in types[i-1]:
#       types[i-1] = [13]
#       return [14]
    else:
      return [14]
  else:
    return types[i]

# %%
def case37(types, i):
  '''
  исправляет г. Москва на регион Москва
  '''
  if (3 in types[i]) and (7 in types[i]):
    if i-1>0 and (4 in types[i-1]):
      types[i] = [3]
      types[i-1] = [4]
    elif i+1<len(types) and (8 in types[i+1]):
      types[i] = [7]
      types[i+1] = [8]
    elif i+1<len(types) and (4 in types[i+1]):
      types[i] = [3]
      types[i+1] = [4]
    elif i-1>0 and (8 in types[i-1]):
      types[i] = [7]
      types[i-1] = [8]
  return types

# %%
def case30(types, i):
  '''
  Если литера между номеров дома — это литера
  '''
  if 30 in types[i]:
    if i-1>0:
      for num in [16, 17, 18, 19, 20]:
        if num in types[i-1]:
          types[i] = [30]
          return types
    elif i+1<len(types):
      for num in [17, 18, 19, 20]:
        if num in types[i+1]:
          types[i] = [30]
          return types
  return types

# %%
special_cases = {
  30:case30,
  22:check_num,
  3:case37,
  7:case37 
}

# %%
def overlaps(values, target):
  '''
  Отвечает на вопрос:"Есть ли у двух сетов общие значения"
  '''
  if isinstance(values, list) or isinstance(values, set):
    for value in values:
      try:
        if value in target:
          return True
      except TypeError:
        if value == target:
          return True
    return False
  else:
    try:
      if values in target:
        return True
    except TypeError:
      if values == target:
        return True
    return False

def get_index(nested_list, element):
  response = []
  for i, array in enumerate(nested_list):
    try:
      if element in array:
        response.append(i)
    except TypeError:
      if element == array:
        response.append(i)
  return response

# %%
def decode_dict(nested_list):
  '''returns no. of type'''
  result = []
  for array in nested_list:
    temp = LUT
    for string in array:
      temp = temp[string]
      if isinstance(temp, int):
        result.append(temp)
        break
  return result

# %%
def search_dict(word, dic):
  '''
  Поиск по словарю. Ищет по всем вложенным рубрикам словаря и возвращает путь к найденному слову
  '''
  if isinstance(dic, dict):
    winners = []
    for key, value in dic.items():
      response = search_dict(word, value)
      if response == True:
        winners.append(key)
      elif isinstance(response, list):
        for instance in response:
          if isinstance(instance, list):
            winners.append([key, *instance])
          else:
            winners.append([key, instance])
      elif isinstance(response, str):
        winners.append([key, response])
    return winners
  elif isinstance(dic, set) or isinstance(dic, list):
    if word in dic:
      return True

# %% [markdown]
# ### Выводы для главного метода

# %%
def output(tokens, types):
  for i, _ in enumerate(types):
    if isinstance(types[i], list):
      if types[i] != [0]:
        print(tokens[i], ' : ', [titles[types[i][j]] for j, _ in enumerate(types[i])])
    else:
      if types[i] != 0:
        print(tokens[i], ' : ', titles[types[i]])

# %%
def to_dict(tokens, types, original = True):
  address = {}
  if original:
    address['original'] = original
  for i, _ in enumerate(types):
    if isinstance(types[i], list):
      if types[i] != [0]:
        try:
          address[titles[types[i][0]]]+= (tokens[i]+ " ")
        except KeyError:
          address[titles[types[i][0]]] = (tokens[i]+ " ")
    else:
      if types[i] != 0:
        try:
          address[titles[types[i]]] += (tokens[i]+ " ")
        except KeyError:
          address[titles[types[i]]] = (tokens[i]+ " ")
  return address

# %% [markdown]
# ### Тот самый метод

# %%
def standardize(string, out = False, original = True):
  '''
  In[]: string with address
  Out[]: dunno
  '''
  tokens = tokenize(string, comma=True)
  types_map = [map_types(x) for x in tokens]  
  for i, types in enumerate(types_map):
    if 22 in types_map[i]:
      types_map[i] = check_num(types_map, i)
  types_map = clear_street(types_map)
  for i, types in enumerate(types_map):  
    if len(types_map[i]) > 1:
      for option in types_map[i]:
        if option in special_cases.keys():
          types_map = special_cases[option](types_map, i)
  if out:
    output(tokens, types_map)
  if original:
    original = string
  return to_dict(tokens, types_map, original)

# %% [markdown]
# # Проверка работоспособности

# %%
ref_gz = pd.read_excel('ref/gz.xlsx')

# %%
order = ['Индекс','Страна','Тип региона','Регион','Тип города','Город', 'Тип района', 'Тип улицы', 'Улица', 'Тип дома', 'Дом', 'литера', 'Тип корпуса/строения', 'Корпус/строение', 'Тип квартиры', 'Номер Квартиры', 'original', 'Не распознано', 'обозначение страны', 'обозначение индекса']

# %%
pd.DataFrame(list(ref_gz['origin'].apply(standardize)), columns=order).to_excel('results/gz.xlsx')

# %%
pd.DataFrame(list(ref_gz['origin'].apply(standardize)), columns=order)
# Out:
#       Индекс                    Страна  Тип региона            Регион  \
# 0    107113                        NaN           г            москва
# 1    129301      российская федерация            г            москва
# 2    111394                        NaN           г            москва
# 3    143406                        NaN     область                NaN
# 4    127051                        NaN           г            москва
# 5    413850                        NaN         обл                NaN
# 6    123995                        NaN           г            москва
# 7    105094                        NaN           г            москва
# 8    664116                        NaN          NaN               NaN
# 9    142000                        NaN          NaN               NaN
# 10   141018                        NaN          NaN               NaN
# 11   241037                        NaN          NaN               NaN
# 12   142060                        NaN     область                NaN
# 13   101000                        NaN          NaN           москва
# 14   125252                        NaN           г            москва
# 15   214000                    россия          обл                NaN
# 16   111672   российская федерация рф           NaN           москва
# 17   167000                        NaN  республика              коми
# 18   115201                        NaN          NaN           москва
# 19       NaN                       NaN          NaN               NaN
# 20   121108                        NaN           г            москва
# 21   398024                        NaN          NaN               NaN
# 22   398059                    россия           NaN               NaN
# 23   119334      российская федерация            г     москва москва
# 24   129515                        NaN           г            москва
# 25   124460                        NaN           г            москва
# 26   115093                        NaN           г            москва
# 27   196084                        NaN           г   санкт-петербург
# 28   127591                        NaN           г            москва
# 29       NaN                       NaN           г            москва
# ..       ...                       ...          ...               ...
# 88   115191      российская федерация            г     москва москва
# 89   123242                        NaN           г            москва
# 90   121059                        NaN          NaN           москва
# 91   127023                        NaN           г            москва
# 92   119048                        NaN           г            москва
# 93   119435                        рф            г            москва
# 94   101000      российская федерация            г            москва
# 95   109341      российская федерация          г г     москва москва
# 96   107143      российская федерация            г            москва
# 97   109145      российская федерация          г г     москва москва
# 98   450005                        NaN          NaN               NaN
# 99   129594                        NaN          NaN               NaN
# 100  163053                        NaN          NaN               NaN
# 101  212059                        NaN           г            москва
# 102  129110                        NaN           г            москва
# 103  123242                        NaN           г            москва
# 104  105082                        NaN          NaN           москва
# 105  125171                        NaN           г            москва
# 106  119991                        NaN           г            москва
# 107  111033   российская федерация рф           NaN           москва
# 108  125167   российская федерация рф           NaN           москва
# 109  109147                        NaN           г            москва
# 110  109147                        NaN           г            москва
# 111  107078                        NaN           г            москва
# 112  109390                        NaN           г            москва
# 113  119002                        NaN           г            москва
# 114  117312                        NaN           г            москва
# 115  107031                        NaN          NaN               NaN
# 116  109240                        NaN           г            москва
# 117  127018                        NaN           г            москва
#
#     Тип города                    Город Тип района       Тип улицы  \
# 0          NaN                      NaN        NaN             ул
# 1          NaN                      NaN        NaN             ул
# 2          NaN                      NaN        NaN             ул
# 3           г   московская красногорск         NaN             ул
# 4          NaN                      NaN        NaN       переулок
# 5           г                 балаково         NaN             ул
# 6          NaN                      NaN        NaN            наб
# 7          NaN                      NaN        NaN             ул
# 8           г                     омск         NaN             ул
# 9           г               домодедово         NaN             пр
# 10         NaN                  мытищи         NaN             ул
# 11         NaN                  брянск         NaN             ул
# 12          с               московская      район              NaN
# 13         NaN                      NaN        NaN             ул
# 14         NaN                      NaN        NaN             ул
# 15          г      смоленская смоленск         NaN             ул
# 16         NaN                почтовый         NaN          улица
# 17          г                сыктывкар         NaN             ул
# 18         NaN                      NaN        NaN             ул
# 19          г                волгоград         NaN             ул
# 20         NaN                      NaN        NaN             ул
# 21          г                   липецк         NaN             ул
# 22          г                   липецк         NaN             ул
# 23         NaN                      NaN        NaN         проезд
# 24         NaN                      NaN        NaN             ул
# 25          г               зеленоград         NaN         проезд
# 26         NaN                      NaN        NaN           ул б
# 27         NaN                      NaN        NaN             ул
# 28         NaN                      NaN        NaN         проезд
# 29         NaN                      NaN        NaN         проезд
# ..         ...                      ...        ...             ...
# 88         NaN                       й         NaN         проезд
# 89         NaN                      NaN        NaN            пер
# 90         NaN                      NaN        NaN             ул
# 91         NaN                      NaN        NaN             ул
# 92         NaN                      NaN        NaN             ул
# 93         NaN                      NaN        NaN            пер
# 94         NaN                      NaN        NaN       переулок
# 95         NaN                      NaN        NaN             ул
# 96         NaN                      NaN        NaN             ул
# 97         NaN                      NaN        NaN             ул
# 98          г                      уфа         NaN             ул
# 99         NaN                      NaN        NaN             ул
# 100         г              архангельск         NaN             NaN
# 101        NaN                      NaN        NaN             ул
# 102        NaN                      NaN        NaN             ул
# 103        NaN                      NaN        NaN             ул
# 104        NaN                      NaN        NaN             ул
# 105        NaN                      NaN        NaN             ул
# 106        NaN                      NaN        NaN             ул
# 107        NaN                почтовый         NaN          улица
# 108        NaN                почтовый         NaN          улица
# 109        NaN                      NaN        NaN             ул
# 110        NaN                      NaN        NaN             ул
# 111        NaN                      NaN        NaN              а
# 112        NaN                      NaN        NaN             ул
# 113        NaN                      NaN        NaN             ул
# 114        NaN                      NaN        NaN             ул
# 115        NaN                      NaN        NaN  ул б переулок
# 116        NaN                      NaN        NaN             NaN
# 117        NaN                      NaN        NaN       переулок
#
#                        Улица Тип дома    Дом литера Тип корпуса/строения  \
# 0                  лобачика        д     11     NaN                  NaN
# 1          бориса галушкина        д     17     NaN                  NaN
# 2                 перовская        д     65     NaN                 стр
# 3            50 лет октября        д     12     NaN                  NaN
# 4             сухаревский м        д      9      а                  стр
# 5          коммунистическая        д    124     NaN                  NaN
# 6              бережковская        д     20     NaN                 стр
# 7              гольяновская        д      6     NaN                  NaN
# 8               27 северная        д     48     NaN                  NaN
# 9               кутузовский        д     18     NaN                  NaN
# 10                 сукромка        д      5     NaN                  NaN
# 11                костычева        д     41     NaN                корп
# 12                 лобаново        д     14     NaN                  NaN
# 13            климентовский        д     12     NaN                 стр
# 14                куусинена        д     21      б                   NaN
# 15                   ленина        д     23     NaN                  NaN
# 16              суздальская      дом      6     NaN                  NaN
# 17             карла маркса       NaN   192     NaN                  NaN
# 18             котляковская        д      8     NaN                  NaN
# 19                     мира        д     21     NaN                  NaN
# 20            кастанаевская        д     36     NaN                корп
# 21                  союзная        д      6     NaN                  NaN
# 22                   фрунзе        д     34     NaN                  NaN
# 23              5 й донской      дом     15     NaN                 стр
# 24       академика королева        д     13     NaN                 стр
# 25                     4801        д      5     NaN                  NaN
# 26             серпуховская       NaN    35     NaN                 стр
# 27            новорощинская        д      4      а                   NaN
# 28             керамический        д     53     NaN                 кор
# 29              гостиничный        д      6     NaN                корп
# ..                       ...      ...    ...    ...                  ...
# 88                рощинский       NaN  4 15     NaN                  NaN
# 89    предтеченский верхний        д     11      а                  стр
# 90                 брянская       NaN     3     NaN                  NaN
# 91         масловка верхняя        д     28     NaN                корп
# 92                  усачева        д     62     NaN                 стр
# 93       большой саввинский        д      9     NaN                 стр
# 94   большой златоустинский      дом      2     NaN                 стр
# 95               люблинская       NaN   163     NaN                  NaN
# 96               тагильская       NaN     4     NaN                  NaN
# 97               привольная       NaN     9     NaN                корп
# 98         50 летие октября        д     20     NaN                  NaN
# 99        4 я марьиной рощи        д     12     NaN                  NaN
# 100    аэропорт архангельск        д      4     NaN                корп
# 101                брянская        д      3     NaN                  NaN
# 102            гиляровского        д     42     NaN                  NaN
# 103             баррикадная        д      8      а                  стр
# 104        большая почтовая        д   36 8     NaN                 стр
# 105      космонавта волкова        д      6      а                   NaN
# 106                 ордынка        д     25     NaN                   с
# 107       золоторожский вал      дом     32     NaN                 стр
# 108  ленинградский проспект    дом д     45     NaN                корп
# 109            марксистская       NaN     4     NaN                  NaN
# 110                      NaN       д      4     NaN                  NaN
# 111                       я       NaN   239     NaN                  NaN
# 112              люблинская        д     16     NaN                  NaN
# 113                   арбат        д     54     NaN                 стр
# 114                вавилова        д      9     NaN                  NaN
# 115               кисельный        д      4     NaN                  NaN
# 116                      NaN       д      8     NaN                  NaN
# 117             октябрьский       NaN     9     NaN                  NaN
#
#     Корпус/строение     Тип квартиры Номер Квартиры  \
# 0               NaN              NaN            NaN
# 1               NaN              NaN            NaN
# 2                1               NaN            NaN
# 3               NaN              NaN            NaN
# 4                1          пом ком           1 56
# 5               NaN              NaN            NaN
# 6                9          комната             27
# 7               NaN              NaN            NaN
# 8               NaN            офис            217
# 9               NaN          кв ком          102 2
# 10              NaN           оф кв            441
# 11               1               кв            126
# 12              NaN              оф             20
# 13              16               NaN            NaN
# 14              NaN              NaN            NaN
# 15              NaN              NaN            NaN
# 16              NaN            офис             32
# 17              NaN              оф              8
# 18              NaN              NaN            NaN
# 19              NaN              кв             48
# 20               1         пом комн            6 7
# 21              NaN              оф            325
# 22              NaN              оф             32
# 23               7               NaN            NaN
# 24               1               NaN            NaN
# 25              NaN              NaN            NaN
# 26               6               NaN            NaN
# 27              NaN              NaN            NaN
# 28               1               оф              1
# 29               2             офис            213
# ..              ...              ...            ...
# 88              NaN              NaN            NaN
# 89               3               NaN            NaN
# 90              NaN              NaN            NaN
# 91               2               NaN            NaN
# 92               1               NaN            NaN
# 93               1             офис            425
# 94               1               NaN            NaN
# 95              NaN   квартира офис             98
# 96              NaN              NaN            NaN
# 97               1    квартира офис             NaN
# 98              NaN              NaN            NaN
# 99              NaN              оф             37
# 100              1               NaN            NaN
# 101             NaN              NaN            NaN
# 102             NaN              NaN            NaN
# 103              5               NaN            NaN
# 104              6               NaN            NaN
# 105             NaN            офис            810
# 106              1               NaN            NaN
# 107             11               NaN            NaN
# 108              1   офис помещение              2
# 109             NaN              NaN            NaN
# 110             NaN              NaN            NaN
# 111             NaN              NaN            NaN
# 112             NaN              NaN            NaN
# 113              1               NaN            NaN
# 114             NaN              NaN            NaN
# 115             NaN              NaN            NaN
# 116             NaN              NaN            NaN
# 117             NaN              NaN            NaN
#
#                                               original  \
# 0               107113, г. Москва, ул. Лобачика, д. 11
# 1    129301, Российская Федерация, г. Москва, Борис...
# 2    111394, Москва г, ул.Перовская, \n\nд.65, стр....
# 3    143406, Московская область, г. Красногорск, ул...
# 4    127051, г. Москва, переулок Сухаревский М.,д.9...
# 5    413850, г. Балаково, Саратовской обл., ул. Ком...
# 6    123995, г. Москва, Бережковская наб., д.20, ст...
# 7             105094, г. Москва ул. Гольяновская, д. 6
# 8    664116, г. Омск, ул. 27 Северная, д.48, офис 2...
# 9    142000, МО, г. Домодедово, Кутузовский пр. д.1...
# 10     Мытищи, 141018, ул. Сукромка, д. 5, оф. кв. 441
# 11   Брянск, 241037, ул. Костычева, д. 41 корп.1 кв...
# 12   Московская область, Домодедовский район, с. Ло...
# 13   МОСКВА, 101000, ул. Климентовский , д. 12, стр...
# 14              125252, Москва г, ул. Куусинена, д.21б
# 15   214000, Россия, Смоленская обл., г. Смоленск, ...
# 16   Страна: Российская Федерация; ОКАТО: 452635790...
# 17   167000, Республика Коми, г. Сыктывкар, ул Карл...
# 18               115201, Москва, ул. Котляковская, д.8
# 19              г. Волгоград, ул. Мира, д. 21, кв. 48.
# 20   121108  г.Москва, ул.Кастанаевская д.36 корп.1...
# 21   398024, г. Липецк, \n\nул. Союзная, д. 6, оф. ...
# 22   398059, Россия, г.Липецк, ул.Фрунзе, д.34, оф....
# 23   119334, , Российская Федерация, г. Москва, Мос...
# 24   129515, г. Москва, ул. Академика Королева, д. ...
# 25   124460, г. Москва, г. Зеленоград, проезд 4801,д.5
# 26     115093, г Москва, ул Серпуховская Б., 35, стр.6
# 27   196084, г. Санкт-Петербург, ул. Новорощинская,...
# 28   127591, г.Москва, Керамический проезд, д.53, к...
# 29     г.Москва,Гостиничный проезд,д.6,корп.2,офис 213
# ..                                                 ...
# 88   115191, Российская Федерация, г. Москва, Москв...
# 89   123242, г. Москва, Предтеченский Верхний пер.,...
# 90                     121059, Москва, ул. Брянская, 3
# 91   127023, г. Москва, ул. Масловка Верхняя, д. 28...
# 92          119048  г. Москва, ул.Усачева, д.62, стр.1
# 93   119435, РФ, г.Москва, Большой Саввинский пер.,...
# 94   101000 Российская Федерация г. Москва Большой ...
# 95   109341, Российская Федерация, г. Москва, Москв...
# 96   107143, Российская Федерация, 77 г. Москва,  Т...
# 97   109145, Российская Федерация, г. Москва, Москв...
# 98            450005, г.Уфа, ул.50-летие Октября, д.20
# 99           129594, 4-я ул.Марьиной Рощи д.12  оф. 37
# 100  163053, г. Архангельск, аэропорт Архангельск, ...
# 101              212059, г. Москва, ул. Брянская, д. 3
# 102         129110, г. Москва, ул. Гиляровского, д. 42
# 103  123242, г. Москва, ул. Баррикадная, д. 8, стр. 5А
# 104  105082, Москва, ул. Большая Почтовая, д. 36, с...
# 105  125171, г. Москва, ул. Космонавта Волкова, д. ...
# 106         119991, г. Москва, ул. Ордынка, д. 25, с.1
# 107  Страна: Российская Федерация; ОКАТО: 452905640...
# 108  Страна: Российская Федерация; ОКАТО: 452775980...
# 109                109147 г. Москва ул. Марксистская 4
# 110             109147, г.Москва, ул.Мраксистская, д.4
# 111                         107078, г. Москва, а/я 239
# 112            109390. г.Москва, ул. Люблинская, д.16
# 113      119002, г. Москва, ул. Арбат, д. 54/2, стр. 1
# 114              117312, г. Москва, ул. Вавилова, д. 9
# 115             107031, ул. Б. Кисельный переулок, д.4
# 116                             109240, г. Москва, д.8
# 117         127018, г. Москва, Октябрьский переулок, 9
#
#                     Не распознано обозначение страны обозначение индекса
# 0                             NaN                NaN                 NaN
# 1                             NaN                NaN                 NaN
# 2                             NaN                NaN                 NaN
# 3                             NaN                NaN                 NaN
# 4                             NaN                NaN                 NaN
# 5                    саратовской                 NaN                 NaN
# 6                             NaN                NaN                 NaN
# 7                             NaN                NaN                 NaN
# 8                              1                 NaN                 NaN
# 9                             мо                 NaN                 NaN
# 10                            NaN                NaN                 NaN
# 11                            NaN                NaN                 NaN
# 12                 домодедовский                 NaN                 NaN
# 13                            NaN                NaN                 NaN
# 14                            NaN                NaN                 NaN
# 15                             8                 NaN                 NaN
# 16   окато 45263579000 субъект 1             страна              индекс
# 17                            NaN                NaN                 NaN
# 18                            NaN                NaN                 NaN
# 19                            NaN                NaN                 NaN
# 20                            NaN                NaN                 NaN
# 21                            NaN                NaN                 NaN
# 22                            NaN                NaN                 NaN
# 23                            NaN                NaN                 NaN
# 24                            NaN                NaN                 NaN
# 25                            NaN                NaN                 NaN
# 26                            NaN                NaN                 NaN
# 27                           лит                 NaN                 NaN
# 28                            NaN                NaN                 NaN
# 29                            NaN                NaN                 NaN
# ..                            ...                ...                 ...
# 88                            NaN                NaN                 NaN
# 89                            NaN                NaN                 NaN
# 90                            NaN                NaN                 NaN
# 91                            NaN                NaN                 NaN
# 92                            NaN                NaN                 NaN
# 93                            NaN                NaN                 NaN
# 94                             8                 NaN                 NaN
# 95                             1                 NaN                 NaN
# 96                            77                 NaN                 NaN
# 97                            NaN                NaN                 NaN
# 98                            NaN                NaN                 NaN
# 99                            NaN                NaN                 NaN
# 100                           NaN                NaN                 NaN
# 101                           NaN                NaN                 NaN
# 102                           NaN                NaN                 NaN
# 103                           NaN                NaN                 NaN
# 104                            7                 NaN                 NaN
# 105                           NaN                NaN                 NaN
# 106                           NaN                NaN                 NaN
# 107    окато 45290564000 субъект             страна              индекс
# 108    окато 45277598000 субъект             страна              индекс
# 109                           NaN                NaN                 NaN
# 110                 мраксистская                 NaN                 NaN
# 111                           NaN                NaN                 NaN
# 112                           NaN                NaN                 NaN
# 113                            2                 NaN                 NaN
# 114                           NaN                NaN                 NaN
# 115                           NaN                NaN                 NaN
# 116                           NaN                NaN                 NaN
# 117                           NaN                NaN                 NaN
#
# [118 rows x 20 columns]
